# %%
import os

# %%
def count_images(folder_path, extensions=None):
    if extensions is None:
        extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    total_images = sum(
        1 for root, _, files in os.walk(folder_path)
        for file in files
        if os.path.splitext(file)[1].lower() in extensions
    )
    print(f"Total images: {total_images}")

# %%
# celeba_dataset_curated
count_images("/home/natalyagrokh/img_datasets/celeba_dataset_curated")
# Out:
# Total images: 111477

# %%
# celeba_dataset_curated
count_images("/home/natalyagrokh/img_datasets/celeba_dataset_curated_3")
# Out:
# Total images: 32790

# %%
# ck_dataset_filtered
count_images("/home/natalyagrokh/img_datasets/ck_dataset_filtered")
# Out:
# Total images: 981

# %%
# combined_datasets_small
count_images("/home/natalyagrokh/img_datasets/combined_datasets_small")
# Out:
# Total images: 0

# %%
# combined_datasets_small_archive
count_images("/home/natalyagrokh/img_datasets/combined_datasets_small_archive")
# Out:
# Total images: 37079

# %%
count_images("/home/natalyagrokh/img_datasets/test_images")
# Out:
# Total images: 500

# %%
# combined_datasets_small_lightcur
count_images("/home/natalyagrokh/img_datasets/combined_datasets_small_lightcur")
# Out:
# Total images: 2

# %%
# combined_datasets_small_copy_rejects
count_images("/home/natalyagrokh/img_datasets/combined_datasets_small_rejects")
# Out:
# Total images: 498

# %%
# test_imgs_faces
count_images("/home/natalyagrokh/img_datasets/test_imgs_faces")
# Out:
# Total images: 412

# %%
# test_debug
count_images("/home/natalyagrokh/img_datasets/test_debug")
# Out:
# Total images: 97

# %%
#test_images
count_images("/home/natalyagrokh/img_datasets/test_images")
# Out:
# Total images: 500

# %%
# combined_datasets_medium_archive
count_images("/home/natalyagrokh/img_datasets/test_images")
# Out:
# Total images: 500

# %%
# combined_datasets_medium_archive
count_images("/home/natalyagrokh/img_datasets/combined_datasets_medium_archive")
# Out:
# Total images: 408312

# %%
# combined_datasets_medium_copy
count_images("/home/natalyagrokh/img_datasets/combined_datasets_medium")
# Out:
# Total images: 0

# %%
# combined_datasets_large_archive
count_images("/home/natalyagrokh/img_datasets/combined_datasets_large_archive")
# Out:
# Total images: 24962

# %%
# combined_datasets_large_copy
count_images("/home/natalyagrokh/img_datasets/combined_datasets_large")
# Out:
# Total images: 0

# %%
# combo_ferckja_dataset
count_images("/home/natalyagrokh/img_datasets/combo_ferckja_dataset_2")
# Out:
# Total images: 51483

# %%
# faces_dataset_curated
count_images("/home/natalyagrokh/img_datasets/faces_dataset_curated")
# Out:
# Total images: 67601

# %%
# fer_2013_dataset
count_images("/home/natalyagrokh/img_datasets/fer_2013_dataset")
# Out:
# Total images: 35887

# %%
# flickr_dataset_curated
count_images("/home/natalyagrokh/img_datasets/flickr_dataset_curated")
# Out:
# Total images: 47559

# %%
# flickr_curated
count_images("/home/natalyagrokh/img_datasets/flickr_curated")
# Out:
# Total images: 1097

# %%
# google_images_curated  
count_images("/home/natalyagrokh/img_datasets/google_images_curated")
# Out:
# Total images: 1930

# %%
# humans_dataset_curated
count_images("/home/natalyagrokh/img_datasets/humans_dataset_curated")
# Out:
# Total images: 132546

# %%
# jaffe_dataset
count_images("/home/natalyagrokh/img_datasets/jaffe_dataset")
# Out:
# Total images: 426

# %%
# lfw_dataset_curated
count_images("/home/natalyagrokh/img_datasets/lfw_dataset_curated")
# Out:
# Total images: 3126

# %%
# pexels_dataset_curated
count_images("/home/natalyagrokh/img_datasets/pexels_dataset_curated")
# Out:
# Total images: 33620

# %%
# wider_face_curated
count_images("/home/natalyagrokh/img_datasets/wider_face_curated")
# Out:
# Total images: 47389
