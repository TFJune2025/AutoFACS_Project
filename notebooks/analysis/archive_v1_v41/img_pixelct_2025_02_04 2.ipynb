# %%
import os
from PIL import Image

# %%
def image_size_range(folder_path, extensions=None):
    if extensions is None:
        extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    sizes = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if os.path.splitext(file)[1].lower() in extensions:
                file_path = os.path.join(root, file)
                try:
                    with Image.open(file_path) as img:
                        sizes.append(img.size)  # (width, height)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    if sizes:
        min_size = min(sizes)
        max_size = max(sizes)
        print(f"Smallest dimensions: {min_size}")
        print(f"Largest dimensions: {max_size}")
    else:
        print("No valid images found.")

# %%
# celeba_dataset
image_size_range("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/lfw_dataset_curated/archive/lfw_unsorted")
# Out:
# Smallest dimensions: (250, 250)
# Largest dimensions: (250, 250)
