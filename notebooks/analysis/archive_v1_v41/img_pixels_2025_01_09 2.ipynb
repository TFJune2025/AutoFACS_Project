# %%
import os
from PIL import Image

# %%
def image_size_range(folder_path, extensions=None):
    if extensions is None:
        extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    sizes = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if os.path.splitext(file)[1].lower() in extensions:
                file_path = os.path.join(root, file)
                try:
                    with Image.open(file_path) as img:
                        sizes.append(img.size)  # (width, height)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    if sizes:
        min_size = min(sizes)
        max_size = max(sizes)
        print(f"Smallest dimensions: {min_size}")
        print(f"Largest dimensions: {max_size}")
    else:
        print("No valid images found.")

# %%
# celeba_dataset
image_size_range("/home/natalyagrokh/img_datasets/celeba_dataset/extracted_images/img_align_celeba_png")
# Out:
# Smallest dimensions: (178, 218)
# Largest dimensions: (178, 218)

# %%
# celeba_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/curated_images/celeba_dataset_curated")
# Out:
# Smallest dimensions: (48, 56)
# Largest dimensions: (192, 269)

# %%
# ck_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/ck_dataset_curated")
# Out:
# Smallest dimensions: (48, 59)
# Largest dimensions: (60, 87)

# %%
# ck_dataset_filtered
image_size_range("/home/natalyagrokh/img_datasets/ck_dataset_filtered")
# Out:
# Smallest dimensions: (48, 48)
# Largest dimensions: (48, 48)

# %%
# combined_datasets
image_size_range("/home/natalyagrokh/img_datasets/combined_datasets")
# Out:
# No valid images found.

# %%
# faces_dataset
image_size_range("/home/natalyagrokh/img_datasets/faces_dataset")
# Out:
# Smallest dimensions: (48, 48)
# Largest dimensions: (8675, 5412)

# %%
# faces_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/curated_images/faces_dataset_curated")
# Out:
# Smallest dimensions: (48, 52)
# Largest dimensions: (3339, 4351)

# %%
# fer_2013_dataset
image_size_range("/home/natalyagrokh/img_datasets/fer_2013_dataset")
# Out:
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1109992.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1109992.jpg'
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_731447.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_731447.jpg'
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1623042.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1623042.jpg'
# Smallest dimensions: (48, 48)
# Largest dimensions: (48, 48)

# %%
# fer_2013_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/fer_2013_dataset_curated")
# Out:
# No valid images found.

# %%
# flickr_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/curated_images/flickr_dataset_curated")
# Out:
# Smallest dimensions: (48, 49)
# Largest dimensions: (3512, 4125)

# %%
# google_images_curated
image_size_range("/home/natalyagrokh/img_datasets/google_images_curated")
# Out:
# Smallest dimensions: (48, 63)
# Largest dimensions: (2291, 3141)

# %%
# google_images_curated  
image_size_range("/home/natalyagrokh/img_datasets/google_images_curated")
# Out:
# Smallest dimensions: (12, 16)
# Largest dimensions: (2291, 3141)

# %%
# humans_dataset
image_size_range("/home/natalyagrokh/img_datasets/humans_dataset")
# Out:
# /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/PIL/Image.py:3186: DecompressionBombWarning: Image size (91287280 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Smallest dimensions: (48, 49)
# Largest dimensions: (8675, 5412)

# %%
# humans_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/humans_dataset_curated")
# Out:
# Smallest dimensions: (48, 50)
# Largest dimensions: (6634, 8023)

# %%
# jaffe_dataset
image_size_range("/home/natalyagrokh/img_datasets/temp_scraped_images/jaffe_dataset")
# Out:
# Smallest dimensions: (256, 256)
# Largest dimensions: (256, 256)

# %%
# jaffe_dataset_2
image_size_range("/home/natalyagrokh/img_datasets/temp_scraped_images/jaffe_dataset_2")
# Out:
# Smallest dimensions: (256, 256)
# Largest dimensions: (256, 256)

# %%
# lfw_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/lfw_dataset_curated")
# Out:
# Smallest dimensions: (48, 52)
# Largest dimensions: (177, 234)

# %%
# mini_imgset
image_size_range("/home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset")
# Out:
# Error processing /home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset/17.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset/17.jpg'
# Error processing /home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset/23.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset/23.jpg'
# Smallest dimensions: (396, 500)
# Largest dimensions: (6000, 4000)

# %%
# pexels_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/curated_images/pexels_dataset_curated")
# Out:
# Smallest dimensions: (48, 49)
# Largest dimensions: (7550, 9660)

# %%
# wider_face_curated
image_size_range("/home/natalyagrokh/img_datasets/wider_face_curated")
# Out:
# Smallest dimensions: (48, 48)
# Largest dimensions: (1442, 1563)

# %%
# fer_2013_dataset
image_size_range("/home/natalyagrokh/img_datasets/fer_2013_dataset")
# Out:
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1109992.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1109992.jpg'
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_731447.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_731447.jpg'
# Error processing /home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1623042.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/fer_2013_dataset/versions/1/test/angry/._PrivateTest_1623042.jpg'
# Smallest dimensions: (48, 48)
# Largest dimensions: (48, 48)

# %%
# pexels_dataset_curated
image_size_range("/home/natalyagrokh/img_datasets/curated_images/pexels_dataset_curated")
# Out:
# Smallest dimensions: (48, 49)
# Largest dimensions: (7550, 9660)

# %%
# pexels_images
image_size_range("/home/natalyagrokh/img_datasets/pexels_images")
# Out:
# Error processing /home/natalyagrokh/img_datasets/pexels_images/._image_4.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images/._image_4.jpg'
# Error processing /home/natalyagrokh/img_datasets/pexels_images/._image_22228.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images/._image_22228.jpg'
# Error processing /home/natalyagrokh/img_datasets/pexels_images/._image_22246.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images/._image_22246.jpg'
# Error processing /home/natalyagrokh/img_datasets/pexels_images/._image_36535.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images/._image_36535.jpg'
# Error processing /home/natalyagrokh/img_datasets/pexels_images/._image_36532.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images/._image_36532.jpg'
# ...

# %%
# pexels_images_2
image_size_range("/home/natalyagrokh/img_datasets/pexels_images_2")
# Out:
# Error processing /home/natalyagrokh/img_datasets/pexels_images_2/image_21670.jpg: cannot identify image file '/home/natalyagrokh/img_datasets/pexels_images_2/image_21670.jpg'
# Smallest dimensions: (1000, 1500)
# Largest dimensions: (8192, 8192)
