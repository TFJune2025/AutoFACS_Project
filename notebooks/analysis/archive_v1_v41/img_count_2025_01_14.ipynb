# %%
import os

# %%
def count_images(folder_path, extensions=None):
    if extensions is None:
        extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    total_images = sum(
        1 for root, _, files in os.walk(folder_path)
        for file in files
        if os.path.splitext(file)[1].lower() in extensions
    )
    print(f"Total images: {total_images}")

# %%
# ck_dataset
count_images("ck_dataset_filtered")
# Out:
# Total images: 981

# %%
# combined_datasets_small
count_images("ck_dataset_images")
# Out:
# Total images: 981

# %%
# combined_datasets_small
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/combined_datasets_small")
# Out:
# Total images: 377513

# %%
# combined_datasets_medium
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/combined_datasets_medium")
# Out:
# Total images: 79837

# %%
# combined_datasets_large
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/combined_datasets_large")
# Out:
# Total images: 100

# %%
# celeba_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/celeba_dataset_curated")
# Out:
# Total images: 111477

# %%
# ck_dataset_filtered
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/ck_dataset_filtered")
# Out:
# Total images: 981

# %%
# faces_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/faces_dataset_curated")
# Out:
# Total images: 67601

# %%
# fer_2013_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/fer_2013_dataset")
# Out:
# Total images: 35887

# %%
# flickr_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/flickr_dataset_curated")
# Out:
# Total images: 47559

# %%
# google_images_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/google_images_curated")
# Out:
# Total images: 965

# %%
# humans_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/humans_dataset_curated")
# Out:
# Total images: 132546

# %%
# jaffe_dataset
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/jaffe_dataset")
# Out:
# Total images: 213

# %%
# lfw_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/lfw_dataset_curated")
# Out:
# Total images: 3126

# %%
# lfw_dataset_curated
count_images("lfw_dataset_curated_2")
# Out:
# Total images: 3039

# %%
# pexels_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_dataset_curated")
# Out:
# Total images: 33620

# %%
# wider_face_dataset_curated
count_images("/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/wider_face_dataset_curated")
# Out:
# Total images: 47389
