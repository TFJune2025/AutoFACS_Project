# %%
import os

# %%
def count_images(folder_path, extensions=None):
    if extensions is None:
        extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    total_images = sum(
        1 for root, _, files in os.walk(folder_path)
        for file in files
        if os.path.splitext(file)[1].lower() in extensions
    )
    print(f"Total images: {total_images}")

# %%
# celeba_dataset
count_images("/home/natalyagrokh/img_datasets/celeba_dataset_curated")

# %%
# celeba_dataset_curated
count_images("/home/natalyagrokh/img_datasets/curated_images/celeba_dataset_curated")
# Out:
# Total images: 0

# %%
# ck_dataset_curated
count_images("/home/natalyagrokh/img_datasets/ck_dataset_curated")
# Out:
# Total images: 34

# %%
# ck_dataset_filtered
count_images("/home/natalyagrokh/img_datasets/ck_dataset_filtered")
# Out:
# Total images: 981

# %%
# combined_datasets
count_images("/home/natalyagrokh/img_datasets/combined_datasets")
# Out:
# Total images: 0

# %%
# faces_dataset
count_images("/home/natalyagrokh/img_datasets/faces_dataset")
# Out:
# Total images: 0

# %%
# faces_dataset_curated
count_images("/home/natalyagrokh/img_datasets/curated_images/faces_dataset_curated")
# Out:
# Total images: 0

# %%
# fer_2013_dataset
count_images("/home/natalyagrokh/img_datasets/fer_2013_dataset")
# Out:
# Total images: 35890

# %%
# fer_2013_dataset_curated
count_images("/home/natalyagrokh/img_datasets/fer_2013_dataset_curated")
# Out:
# Total images: 5950

# %%
# flickr_dataset_curated
count_images("/home/natalyagrokh/img_datasets/curated_images/flickr_dataset_curated")
# Out:
# Total images: 47559

# %%
# flickr_images_1
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_1")
# Out:
# Total images: 26

# %%
# flickr_images_2
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_2")
# Out:
# Total images: 27

# %%
# flickr_images_3
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_3")
# Out:
# Total images: 32

# %%
# flickr_images_4
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_4")
# Out:
# Total images: 42

# %%
# flickr_images_5
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_5")
# Out:
# Total images: 37

# %%
# flickr_images_6
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_6")
# Out:
# Total images: 43

# %%
# flickr_images_7
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_7")
# Out:
# Total images: 38

# %%
# flickr_images_8
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_8")
# Out:
# Total images: 38

# %%
# flickr_images_9
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_9")
# Out:
# Total images: 26

# %%
# flickr_images_10
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_10")
# Out:
# Total images: 49

# %%
# flickr_dataset_curated
count_images = "/home/natalyagrokh/img_datasets/curated_images/flickr_dataset_curated"

# %%
# google_images_curated  
count_images("/home/natalyagrokh/img_datasets/google_images_curated")
# Out:
# Total images: 965

# %%
# humans_dataset_curated
count_images("/home/natalyagrokh/img_datasets/humans_dataset_curated")
# Out:
# Total images: 132546

# %%
# jaffe_dataset
count_images("/home/natalyagrokh/img_datasets/jaffe_dataset")
# Out:
# Total images: 0

# %%
# jaffe_dataset
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/jaffe_dataset")
# Out:
# Total images: 213

# %%
# lfw_dataset_curated
count_images("/home/natalyagrokh/img_datasets/lfw_dataset_curated")
# Out:
# Total images: 3126

# %%
# jaffe_dataset
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/mini_imgset")
# Out:
# Total images: 60

# %%
# pexels_images
count_images("/home/natalyagrokh/img_datasets/pexels_images")
# Out:
# Total images: 36793

# %%
# pexels_images_2
count_images("/home/natalyagrokh/img_datasets/pexels_images_2")
# Out:
# Total images: 19127

# %%
# pexels_dataset_curated
count_images("/home/natalyagrokh/img_datasets/curated_images/pexels_dataset_curated")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # pexels_dataset_curated
# ----> 2 count_images("/home/natalyagrokh/img_datasets/curated_images/pexels_dataset_curated")
#
# TypeError: 'str' object is not callable

# %%
# temp_images_scraped/flickr_images_1
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/flickr_images_1")
# Out:
# Total images: 4369

# %%
# wider_face_curated
count_images("/home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images")
# Out:
# Total images: 0

# %%
# wider_face_curated
count_images("/home/natalyagrokh/img_datasets/wider_face_curated")
# Out:
# Total images: 47389

# %%
# unsplash_lite_dataset
count_images("/home/natalyagrokh/img_datasets/unsplash_lite_dataset")
# Out:
# Total images: 0

# %%
# img_datasets
count_images("/home/natalyagrokh/img_datasets")
# Out:
# Total images: 279468
