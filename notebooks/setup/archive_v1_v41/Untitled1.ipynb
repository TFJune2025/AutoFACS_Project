# %%
import boto3
import gradio
print("Boto3 and Gradio imports successful!")
# Out:
# Boto3 and Gradio imports successful!

# %%
import gradio as gr
print("Gradio version:", gr.__version__)
from autogluon.tabular import TabularPredictor
print("AutoGluon is successfully installed!")
# Out:
# Gradio version: 4.20.0
# AutoGluon is successfully installed!

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Print versions to confirm compatibility
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 1.26.4
# Pandas: 2.2.3

# %%
# Core Python Libraries
import os
import sys
import json
import math
import logging
import datetime

# Scientific Computing and Data Processing
import numpy as np
import pandas as pd
import scipy
import sklearn
import statsmodels
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow and Related Libraries
import tensorflow as tf
from keras.models import Sequential

# Hugging Face and Related Libraries
from transformers import pipeline, AutoTokenizer, AutoModel
import datasets
from huggingface_hub import login

# Gradio and Related Libraries
import gradio as gr

# AutoGluon Libraries
from autogluon.tabular import TabularPredictor
from autogluon.multimodal import MultiModalPredictor
from autogluon.timeseries import TimeSeriesPredictor

# Visualization
import altair as alt
import plotly
import seaborn
import matplotlib.pyplot as plt

# AWS SDK and Networking
import boto3
from botocore.exceptions import NoCredentialsError
import requests
from urllib3.exceptions import HTTPError

# Asynchronous Networking
import aiohttp
import async_timeout

# Utilities and Miscellaneous
import tqdm
import yaml
import jsonschema
from fastapi import FastAPI
import uvicorn

# Other Libraries
import pydantic
import networkx as nx

# Confirm All Imports
print("All imports completed successfully!")
# Out:
# 2024-12-24 15:28:22.541207: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All imports completed successfully!

# %%
from autogluon.timeseries import TimeSeriesPredictor
print("AutoGluon TimeSeries Predictor imported successfully!")
# Out:
# AutoGluon TimeSeries Predictor imported successfully!
