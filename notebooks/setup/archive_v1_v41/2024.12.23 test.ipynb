# %%
import torch
import torchvision
import gradio as gr
from autogluon.tabular import TabularPredictor

print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("Gradio:", gr.__version__)
print("AutoGluon Tabular successfully imported!")
# Out:
# Torch: 2.2.2
# Torchvision: 0.17.2
# Gradio: 4.44.1
# AutoGluon Tabular successfully imported!

# %%
# Core Python Libraries
import os
import sys
import json
import math
import logging
import datetime

# Scientific Computing and Data Processing
import numpy as np
import pandas as pd
import scipy
import sklearn
import statsmodels
import matplotlib.pyplot as plt
import seaborn as sns

# PyTorch and Related Libraries
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchmetrics
from torchmetrics import Accuracy

# PyTorch Lightning (if installed)
try:
    import pytorch_lightning as pl
except ImportError:
    print("PyTorch Lightning not installed.")

# Hugging Face and Transformers
from transformers import pipeline, AutoTokenizer, AutoModel
import datasets

# Image Processing
import cv2
from PIL import Image
import imageio

# AWS SDK (if relevant to your workflow)
import boto3

# Async Libraries
import aiohttp
import async_timeout

# Utilities and Miscellaneous
import tqdm
import yaml
import requests
import jsonschema

# Visualization and Graphing
import plotly
import networkx as nx
import altair as alt

# FastAPI and Web Frameworks
try:
    from fastapi import FastAPI
    import uvicorn
except ImportError:
    print("FastAPI or Uvicorn not installed.")

# Machine Learning and Optimization
try:
    import xgboost as xgb
    import lightgbm as lgb
    from catboost import CatBoostClassifier
except ImportError:
    print("XGBoost, LightGBM, or CatBoost not installed.")

# Gradio for UI
import gradio as gr

# AutoGluon Libraries
from autogluon.tabular import TabularPredictor

# Confirm Imports
print("All imports completed successfully!")
# Out:
# All imports completed successfully!

# %%
import torch
import gradio as gr
import altair as alt
import cv2
from autogluon.tabular import TabularPredictor

print("Torch version:", torch.__version__)
print("Gradio version:", gr.__version__)
print("Altair version:", alt.__version__)
print("OpenCV version:", cv2.__version__)
print("AutoGluon successfully imported!")
# Out:
# Torch version: 2.2.2
# Gradio version: 4.44.1
# Altair version: 5.5.0
# OpenCV version: 4.10.0
# AutoGluon successfully imported!
