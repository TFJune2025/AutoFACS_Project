# %%
# Core Libraries
import numpy as np
import pandas as pd
import sklearn

# NLP Libraries
import nltk
import spacy
from transformers import pipeline

# Computer Vision
import cv2
import mediapipe as mp

# Deep Learning
import tensorflow as tf
import torch

# Video Processing
import moviepy.editor as mp_editor
import gradio
# Out:
# 2024-12-17 14:45:03.740084: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2024-12-17 13:21:01.464815: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.16.2

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
import mediapipe as mp
print(mp.__version__)
# Out:
# 0.10.20

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2024-12-17 14:52:28.063866: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.16.2

# %%
from transformers import pipeline
qa_pipeline = pipeline("question-answering")
print("Hugging Face Transformers is working!")
# Out:
# 2024-12-19 08:08:42.892585: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu
# Hugging Face Transformers is working!
