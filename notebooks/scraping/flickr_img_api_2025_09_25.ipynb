# %%
import requests
import os
import time
import json
from datetime import datetime
from dotenv import load_dotenv
from pathlib import Path

# %%
# global configurations
base_url = "https://www.flickr.com/services/rest/"
method = "flickr.photos.search"
commercial_licenses = "4,7,9,10" # (CC BY, No known restrictions, US Gov, CC0)

OUTPUT_FOLDER = "/Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped"
file_path="/Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/downloaded_urls_flickr_2025.json"

# %%
# Loads a set of previously downloaded URLs from a specific JSON file
def load_downloaded_urls(file_path):
    if os.path.exists(file_path):
        try:
            with open(file_path, "r") as f:
                urls = set(json.load(f))
            print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
            return urls
        except json.JSONDecodeError:
            print(f"Warning: {file_path} is empty or corrupted. Starting fresh for this query.")
            return set()
    return set()

# %%
# Persistent Tracking: saves the set of downloaded URLs to a specific JSON file.
def save_downloaded_urls(downloaded_urls, file_path):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f, indent=4)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Recursively scans all subdirectories in the root_dir to find the
    # highest number in filenames like 'image_xxxx.jpg'. 
def find_highest_image_number(root_dir):
    highest_num = 0
    root_path = Path(root_dir)
    all_image_files = list(root_path.rglob("image_*.jpg")) + list(root_path.rglob("image_*.jpeg"))
    
    for file_path in all_image_files:
        try:
            num_str = file_path.stem.split('_')[1]
            num = int(num_str)
            if num > highest_num:
                highest_num = num
        except (IndexError, ValueError):
            continue
            
    print(f"Found highest existing image number: {highest_num}")
    return highest_num

# %%
# Generate queries related to people
def generate_people_related_queries():
    queries = ["candid+portrait", "street+photography", "spectator+reaction",
        "fan+celebration", "commuter", "person+laughing", "heated+discussion",
        "intense+concentration", "joyful", "pensive+person", "annoyed+face",
        "worried+person", "thoughtful+expression", "people+talking", "faces", 
        "smiling", "groups", "friends", "family", "couples", "individuals", 
        "emotions", "sad", "angry", "happy", "joyful","suspicious", "disgust","fear", 
        "rage","human faces","profession", "human", "people", "portraits", "contempt"
    ] 
    return queries

# %%
# Downloads a single image and saves its corresponding metadata.
def download_image(url, output_folder, image_filename, metadata, metadata_filename):
    try:
        response = requests.get(url, stream=True, timeout=120)
        response.raise_for_status()
        
        file_path = os.path.join(output_folder, image_filename)
        with open(file_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {image_filename}")

        # Save metadata
        metadata_path = os.path.join(output_folder, metadata_filename)
        with open(metadata_path, "w") as f:
            json.dump(metadata, f, indent=4)
        print(f"Saved Metadata: {metadata_filename}")
        
        return True
    except requests.exceptions.HTTPError as e:
        print(f"  HTTP error for {url}: {e}")
        return False
    except Exception as e:
        print(f"Failed to download {url}: {e}")
        return False

# %%
# Exhaustively fetches and saves images for a SINGLE query, saving all files
    # and tracking information into the specified 'save_dir'.
    # Returns the number of images it successfully downloaded
def auto_flickr_images(api_key, query, save_dir, start_index, batch_size=100, max_requests=3600):
    
    api_call_count = 0
    page = 1
    
    tracking_file_path = os.path.join(save_dir, "downloaded_urls.json")
    downloaded_urls = load_downloaded_urls(tracking_file_path)

    total_downloaded_for_query = 0

    while api_call_count < max_requests:
        params = {
            "method": method, "api_key": api_key, "text": query,
            "license": commercial_licenses, "format": "json", "nojsoncallback": 1,
            "per_page": batch_size, "page": page,
            "extras": "url_o,url_m,license,owner_name,tags"
        }

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"API request failed: {e}. Stopping this query.")
            break
        
        api_call_count += 1
        print(f"API Call {api_call_count}/{max_requests} for query '{query}', page {page}.")

        data = response.json()
        photos = data.get("photos", {}).get("photo", [])

        if not photos:
            print(f"No more photos found for query '{query}'. This query is complete.")
            break

        new_downloads_this_page = 0
        for photo in photos:
            photo_url = photo.get("url_o") or photo.get("url_m")
            if not photo_url or photo_url in downloaded_urls:
                continue

            metadata = {
                "photo_id": photo.get("id"), 
                "owner_name": photo.get("ownername"),
                "license_id": photo.get("license"), 
                "tags": photo.get("tags"),
                "source_url": photo_url
            }
            
            # MODIFIED: Use the start_index passed to the function
            filename_base = f"image_{start_index + total_downloaded_for_query:04d}" # Added 4-digit padding
            image_filename = f"{filename_base}.jpg"
            metadata_filename = f"{filename_base}.json"
        
            if download_image(photo_url, save_dir, image_filename, metadata, metadata_filename):
                downloaded_urls.add(photo_url)
                save_downloaded_urls(downloaded_urls, tracking_file_path)
                total_downloaded_for_query += 1
                new_downloads_this_page += 1

        if new_downloads_this_page == 0 and len(photos) > 0:
            print(f"No new images found on page {page}. Assuming query '{query}' is complete.")
            break
        
        page += 1
        time.sleep(1.1)

    print(f"\nFinished query '{query}'. Downloaded a total of {total_downloaded_for_query} new images for this query.")
    return total_downloaded_for_query

# %%
# --- MAIN EXECUTION BLOCK ---
if __name__ == "__main__":
    
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)

    # Load variables from .env
    load_dotenv()

    API_KEY = os.getenv("FLICKR_API_KEY")

    if not API_KEY:
        raise ValueError("FLICKR_API_KEY not found in .env file")
    
    # 1. Find the highest existing number across all subfolders first.
    highest_number = find_highest_image_number(OUTPUT_FOLDER)
    current_image_counter = highest_number + 1
    print(f"Starting new session. Numbering will begin at: {current_image_counter}")
    
    all_queries = generate_people_related_queries()
    print(f"Found {len(all_queries)} queries to process for Flickr.\n{'='*50}")

    for query in all_queries:
        print(f"\nProcessing query: '{query}'")
        
        output_folder_for_query = os.path.join(OUTPUT_FOLDER, query.replace('+', '_'))
        os.makedirs(output_folder_for_query, exist_ok=True)
        
        # 2. Pass the current counter and get back the number of new files.
        newly_downloaded_count = auto_flickr_images(
            api_key=API_KEY,
            query=query,
            save_dir=output_folder_for_query,
            start_index=current_image_counter,
            batch_size=100,
            max_requests=3600
        )
        # 3. Increment the main counter.
        current_image_counter += newly_downloaded_count

        print(f"{'='*50}")

    print(f"\nAll queries have been processed. Next session will start after image_{current_image_counter - 1}.")
# Out:
# Found highest existing image number: 2006
# Starting new session. Numbering will begin at: 2007
# Found 36 queries to process for Flickr.
# ==================================================
#
# Processing query: 'candid+portrait'
# Loaded 419 previously downloaded URLs from /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 1/3600 for query 'candid+portrait', page 1.
# Downloaded: image_2007.jpg
# Saved Metadata: image_2007.json
# Saved 420 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2008.jpg
# Saved Metadata: image_2008.json
# Saved 421 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2009.jpg
# Saved Metadata: image_2009.json
# Saved 422 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2010.jpg
# Saved Metadata: image_2010.json
# Saved 423 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2011.jpg
# Saved Metadata: image_2011.json
# Saved 424 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2012.jpg
# Saved Metadata: image_2012.json
# Saved 425 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2013.jpg
# Saved Metadata: image_2013.json
# Saved 426 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2014.jpg
# Saved Metadata: image_2014.json
# Saved 427 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 2/3600 for query 'candid+portrait', page 2.
# Downloaded: image_2015.jpg
# Saved Metadata: image_2015.json
# Saved 428 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2016.jpg
# Saved Metadata: image_2016.json
# Saved 429 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2017.jpg
# Saved Metadata: image_2017.json
# Saved 430 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2018.jpg
# Saved Metadata: image_2018.json
# Saved 431 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2019.jpg
# Saved Metadata: image_2019.json
# Saved 432 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2020.jpg
# Saved Metadata: image_2020.json
# Saved 433 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2021.jpg
# Saved Metadata: image_2021.json
# Saved 434 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2022.jpg
# Saved Metadata: image_2022.json
# Saved 435 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2023.jpg
# Saved Metadata: image_2023.json
# Saved 436 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2024.jpg
# Saved Metadata: image_2024.json
# Saved 437 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2025.jpg
# Saved Metadata: image_2025.json
# Saved 438 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 3/3600 for query 'candid+portrait', page 3.
# Downloaded: image_2026.jpg
# Saved Metadata: image_2026.json
# Saved 439 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2027.jpg
# Saved Metadata: image_2027.json
# Saved 440 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2028.jpg
# Saved Metadata: image_2028.json
# Saved 441 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2029.jpg
# Saved Metadata: image_2029.json
# Saved 442 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 4/3600 for query 'candid+portrait', page 4.
# Downloaded: image_2030.jpg
# Saved Metadata: image_2030.json
# Saved 443 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2031.jpg
# Saved Metadata: image_2031.json
# Saved 444 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2032.jpg
# Saved Metadata: image_2032.json
# Saved 445 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2033.jpg
# Saved Metadata: image_2033.json
# Saved 446 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2034.jpg
# Saved Metadata: image_2034.json
# Saved 447 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2035.jpg
# Saved Metadata: image_2035.json
# Saved 448 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2036.jpg
# Saved Metadata: image_2036.json
# Saved 449 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2037.jpg
# Saved Metadata: image_2037.json
# Saved 450 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2038.jpg
# Saved Metadata: image_2038.json
# Saved 451 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2039.jpg
# Saved Metadata: image_2039.json
# Saved 452 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2040.jpg
# Saved Metadata: image_2040.json
# Saved 453 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# Downloaded: image_2041.jpg
# Saved Metadata: image_2041.json
# Saved 454 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 5/3600 for query 'candid+portrait', page 5.
# Downloaded: image_2042.jpg
# Saved Metadata: image_2042.json
# Saved 455 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/candid_portrait/downloaded_urls.json.
# API Call 6/3600 for query 'candid+portrait', page 6.
# No more photos found for query 'candid+portrait'. This query is complete.
#
# Finished query 'candid+portrait'. Downloaded a total of 36 new images for this query.
# ==================================================
#
# Processing query: 'street+photography'
# Loaded 561 previously downloaded URLs from /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 1/3600 for query 'street+photography', page 1.
# Downloaded: image_2043.jpg
# Saved Metadata: image_2043.json
# Saved 562 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2044.jpg
# Saved Metadata: image_2044.json
# Saved 563 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2045.jpg
# Saved Metadata: image_2045.json
# Saved 564 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 2/3600 for query 'street+photography', page 2.
# Downloaded: image_2046.jpg
# Saved Metadata: image_2046.json
# Saved 565 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2047.jpg
# Saved Metadata: image_2047.json
# Saved 566 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 3/3600 for query 'street+photography', page 3.
# Downloaded: image_2048.jpg
# Saved Metadata: image_2048.json
# Saved 567 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2049.jpg
# Saved Metadata: image_2049.json
# Saved 568 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2050.jpg
# Saved Metadata: image_2050.json
# Saved 569 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2051.jpg
# Saved Metadata: image_2051.json
# Saved 570 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 4/3600 for query 'street+photography', page 4.
# Downloaded: image_2052.jpg
# Saved Metadata: image_2052.json
# Saved 571 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 5/3600 for query 'street+photography', page 5.
# Downloaded: image_2053.jpg
# Saved Metadata: image_2053.json
# Saved 572 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2054.jpg
# Saved Metadata: image_2054.json
# Saved 573 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 6/3600 for query 'street+photography', page 6.
# Downloaded: image_2055.jpg
# Saved Metadata: image_2055.json
# Saved 574 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2056.jpg
# Saved Metadata: image_2056.json
# Saved 575 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2057.jpg
# Saved Metadata: image_2057.json
# Saved 576 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2058.jpg
# Saved Metadata: image_2058.json
# Saved 577 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2059.jpg
# Saved Metadata: image_2059.json
# Saved 578 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2060.jpg
# Saved Metadata: image_2060.json
# Saved 579 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2061.jpg
# Saved Metadata: image_2061.json
# Saved 580 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2062.jpg
# Saved Metadata: image_2062.json
# Saved 581 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2063.jpg
# Saved Metadata: image_2063.json
# Saved 582 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2064.jpg
# Saved Metadata: image_2064.json
# Saved 583 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2065.jpg
# Saved Metadata: image_2065.json
# Saved 584 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2066.jpg
# Saved Metadata: image_2066.json
# Saved 585 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2067.jpg
# Saved Metadata: image_2067.json
# Saved 586 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2068.jpg
# Saved Metadata: image_2068.json
# Saved 587 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2069.jpg
# Saved Metadata: image_2069.json
# Saved 588 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2070.jpg
# Saved Metadata: image_2070.json
# Saved 589 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2071.jpg
# Saved Metadata: image_2071.json
# Saved 590 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2072.jpg
# Saved Metadata: image_2072.json
# Saved 591 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2073.jpg
# Saved Metadata: image_2073.json
# Saved 592 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2074.jpg
# Saved Metadata: image_2074.json
# Saved 593 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2075.jpg
# Saved Metadata: image_2075.json
# Saved 594 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2076.jpg
# Saved Metadata: image_2076.json
# Saved 595 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2077.jpg
# Saved Metadata: image_2077.json
# Saved 596 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2078.jpg
# Saved Metadata: image_2078.json
# Saved 597 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2079.jpg
# Saved Metadata: image_2079.json
# Saved 598 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2080.jpg
# Saved Metadata: image_2080.json
# Saved 599 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2081.jpg
# Saved Metadata: image_2081.json
# Saved 600 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2082.jpg
# Saved Metadata: image_2082.json
# Saved 601 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2083.jpg
# Saved Metadata: image_2083.json
# Saved 602 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2084.jpg
# Saved Metadata: image_2084.json
# Saved 603 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2085.jpg
# Saved Metadata: image_2085.json
# Saved 604 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2086.jpg
# Saved Metadata: image_2086.json
# Saved 605 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2087.jpg
# Saved Metadata: image_2087.json
# Saved 606 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2088.jpg
# Saved Metadata: image_2088.json
# Saved 607 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2089.jpg
# Saved Metadata: image_2089.json
# Saved 608 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2090.jpg
# Saved Metadata: image_2090.json
# Saved 609 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2091.jpg
# Saved Metadata: image_2091.json
# Saved 610 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2092.jpg
# Saved Metadata: image_2092.json
# Saved 611 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2093.jpg
# Saved Metadata: image_2093.json
# Saved 612 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 7/3600 for query 'street+photography', page 7.
# Downloaded: image_2094.jpg
# Saved Metadata: image_2094.json
# Saved 613 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2095.jpg
# Saved Metadata: image_2095.json
# Saved 614 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2096.jpg
# Saved Metadata: image_2096.json
# Saved 615 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2097.jpg
# Saved Metadata: image_2097.json
# Saved 616 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2098.jpg
# Saved Metadata: image_2098.json
# Saved 617 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2099.jpg
# Saved Metadata: image_2099.json
# Saved 618 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2100.jpg
# Saved Metadata: image_2100.json
# Saved 619 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2101.jpg
# Saved Metadata: image_2101.json
# Saved 620 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2102.jpg
# Saved Metadata: image_2102.json
# Saved 621 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2103.jpg
# Saved Metadata: image_2103.json
# Saved 622 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2104.jpg
# Saved Metadata: image_2104.json
# Saved 623 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2105.jpg
# Saved Metadata: image_2105.json
# Saved 624 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2106.jpg
# Saved Metadata: image_2106.json
# Saved 625 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2107.jpg
# Saved Metadata: image_2107.json
# Saved 626 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2108.jpg
# Saved Metadata: image_2108.json
# Saved 627 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2109.jpg
# Saved Metadata: image_2109.json
# Saved 628 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2110.jpg
# Saved Metadata: image_2110.json
# Saved 629 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2111.jpg
# Saved Metadata: image_2111.json
# Saved 630 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2112.jpg
# Saved Metadata: image_2112.json
# Saved 631 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2113.jpg
# Saved Metadata: image_2113.json
# Saved 632 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2114.jpg
# Saved Metadata: image_2114.json
# Saved 633 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2115.jpg
# Saved Metadata: image_2115.json
# Saved 634 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2116.jpg
# Saved Metadata: image_2116.json
# Saved 635 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2117.jpg
# Saved Metadata: image_2117.json
# Saved 636 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2118.jpg
# Saved Metadata: image_2118.json
# Saved 637 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2119.jpg
# Saved Metadata: image_2119.json
# Saved 638 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2120.jpg
# Saved Metadata: image_2120.json
# Saved 639 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2121.jpg
# Saved Metadata: image_2121.json
# Saved 640 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2122.jpg
# Saved Metadata: image_2122.json
# Saved 641 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2123.jpg
# Saved Metadata: image_2123.json
# Saved 642 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2124.jpg
# Saved Metadata: image_2124.json
# Saved 643 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2125.jpg
# Saved Metadata: image_2125.json
# Saved 644 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2126.jpg
# Saved Metadata: image_2126.json
# Saved 645 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2127.jpg
# Saved Metadata: image_2127.json
# Saved 646 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2128.jpg
# Saved Metadata: image_2128.json
# Saved 647 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2129.jpg
# Saved Metadata: image_2129.json
# Saved 648 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2130.jpg
# Saved Metadata: image_2130.json
# Saved 649 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2131.jpg
# Saved Metadata: image_2131.json
# Saved 650 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2132.jpg
# Saved Metadata: image_2132.json
# Saved 651 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2133.jpg
# Saved Metadata: image_2133.json
# Saved 652 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2134.jpg
# Saved Metadata: image_2134.json
# Saved 653 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2135.jpg
# Saved Metadata: image_2135.json
# Saved 654 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2136.jpg
# Saved Metadata: image_2136.json
# Saved 655 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2137.jpg
# Saved Metadata: image_2137.json
# Saved 656 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2138.jpg
# Saved Metadata: image_2138.json
# Saved 657 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2139.jpg
# Saved Metadata: image_2139.json
# Saved 658 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2140.jpg
# Saved Metadata: image_2140.json
# Saved 659 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2141.jpg
# Saved Metadata: image_2141.json
# Saved 660 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2142.jpg
# Saved Metadata: image_2142.json
# Saved 661 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2143.jpg
# Saved Metadata: image_2143.json
# Saved 662 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2144.jpg
# Saved Metadata: image_2144.json
# Saved 663 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2145.jpg
# Saved Metadata: image_2145.json
# Saved 664 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2146.jpg
# Saved Metadata: image_2146.json
# Saved 665 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2147.jpg
# Saved Metadata: image_2147.json
# Saved 666 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2148.jpg
# Saved Metadata: image_2148.json
# Saved 667 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2149.jpg
# Saved Metadata: image_2149.json
# Saved 668 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2150.jpg
# Saved Metadata: image_2150.json
# Saved 669 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2151.jpg
# Saved Metadata: image_2151.json
# Saved 670 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2152.jpg
# Saved Metadata: image_2152.json
# Saved 671 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2153.jpg
# Saved Metadata: image_2153.json
# Saved 672 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2154.jpg
# Saved Metadata: image_2154.json
# Saved 673 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2155.jpg
# Saved Metadata: image_2155.json
# Saved 674 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2156.jpg
# Saved Metadata: image_2156.json
# Saved 675 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2157.jpg
# Saved Metadata: image_2157.json
# Saved 676 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2158.jpg
# Saved Metadata: image_2158.json
# Saved 677 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2159.jpg
# Saved Metadata: image_2159.json
# Saved 678 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2160.jpg
# Saved Metadata: image_2160.json
# Saved 679 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2161.jpg
# Saved Metadata: image_2161.json
# Saved 680 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2162.jpg
# Saved Metadata: image_2162.json
# Saved 681 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2163.jpg
# Saved Metadata: image_2163.json
# Saved 682 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2164.jpg
# Saved Metadata: image_2164.json
# Saved 683 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2165.jpg
# Saved Metadata: image_2165.json
# Saved 684 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2166.jpg
# Saved Metadata: image_2166.json
# Saved 685 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2167.jpg
# Saved Metadata: image_2167.json
# Saved 686 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2168.jpg
# Saved Metadata: image_2168.json
# Saved 687 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2169.jpg
# Saved Metadata: image_2169.json
# Saved 688 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2170.jpg
# Saved Metadata: image_2170.json
# Saved 689 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2171.jpg
# Saved Metadata: image_2171.json
# Saved 690 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2172.jpg
# Saved Metadata: image_2172.json
# Saved 691 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2173.jpg
# Saved Metadata: image_2173.json
# Saved 692 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2174.jpg
# Saved Metadata: image_2174.json
# Saved 693 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2175.jpg
# Saved Metadata: image_2175.json
# Saved 694 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2176.jpg
# Saved Metadata: image_2176.json
# Saved 695 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2177.jpg
# Saved Metadata: image_2177.json
# Saved 696 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2178.jpg
# Saved Metadata: image_2178.json
# Saved 697 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2179.jpg
# Saved Metadata: image_2179.json
# Saved 698 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2180.jpg
# Saved Metadata: image_2180.json
# Saved 699 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2181.jpg
# Saved Metadata: image_2181.json
# Saved 700 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2182.jpg
# Saved Metadata: image_2182.json
# Saved 701 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2183.jpg
# Saved Metadata: image_2183.json
# Saved 702 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2184.jpg
# Saved Metadata: image_2184.json
# Saved 703 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2185.jpg
# Saved Metadata: image_2185.json
# Saved 704 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2186.jpg
# Saved Metadata: image_2186.json
# Saved 705 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2187.jpg
# Saved Metadata: image_2187.json
# Saved 706 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2188.jpg
# Saved Metadata: image_2188.json
# Saved 707 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2189.jpg
# Saved Metadata: image_2189.json
# Saved 708 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2190.jpg
# Saved Metadata: image_2190.json
# Saved 709 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# API Call 8/3600 for query 'street+photography', page 8.
# Downloaded: image_2191.jpg
# Saved Metadata: image_2191.json
# Saved 710 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2192.jpg
# Saved Metadata: image_2192.json
# Saved 711 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2193.jpg
# Saved Metadata: image_2193.json
# Saved 712 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2194.jpg
# Saved Metadata: image_2194.json
# Saved 713 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2195.jpg
# Saved Metadata: image_2195.json
# Saved 714 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2196.jpg
# Saved Metadata: image_2196.json
# Saved 715 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2197.jpg
# Saved Metadata: image_2197.json
# Saved 716 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2198.jpg
# Saved Metadata: image_2198.json
# Saved 717 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2199.jpg
# Saved Metadata: image_2199.json
# Saved 718 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2200.jpg
# Saved Metadata: image_2200.json
# Saved 719 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2201.jpg
# Saved Metadata: image_2201.json
# Saved 720 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2202.jpg
# Saved Metadata: image_2202.json
# Saved 721 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2203.jpg
# Saved Metadata: image_2203.json
# Saved 722 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2204.jpg
# Saved Metadata: image_2204.json
# Saved 723 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2205.jpg
# Saved Metadata: image_2205.json
# Saved 724 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2206.jpg
# Saved Metadata: image_2206.json
# Saved 725 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2207.jpg
# Saved Metadata: image_2207.json
# Saved 726 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2208.jpg
# Saved Metadata: image_2208.json
# Saved 727 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2209.jpg
# Saved Metadata: image_2209.json
# Saved 728 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2210.jpg
# Saved Metadata: image_2210.json
# Saved 729 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2211.jpg
# Saved Metadata: image_2211.json
# Saved 730 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2212.jpg
# Saved Metadata: image_2212.json
# Saved 731 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2213.jpg
# Saved Metadata: image_2213.json
# Saved 732 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2214.jpg
# Saved Metadata: image_2214.json
# Saved 733 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2215.jpg
# Saved Metadata: image_2215.json
# Saved 734 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2216.jpg
# Saved Metadata: image_2216.json
# Saved 735 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2217.jpg
# Saved Metadata: image_2217.json
# Saved 736 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2218.jpg
# Saved Metadata: image_2218.json
# Saved 737 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2219.jpg
# Saved Metadata: image_2219.json
# Saved 738 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2220.jpg
# Saved Metadata: image_2220.json
# Saved 739 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2221.jpg
# Saved Metadata: image_2221.json
# Saved 740 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2222.jpg
# Saved Metadata: image_2222.json
# Saved 741 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2223.jpg
# Saved Metadata: image_2223.json
# Saved 742 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2224.jpg
# Saved Metadata: image_2224.json
# Saved 743 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2225.jpg
# Saved Metadata: image_2225.json
# Saved 744 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2226.jpg
# Saved Metadata: image_2226.json
# Saved 745 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_2227.jpg
# Saved Metadata: image_2227.json
# Saved 746 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/flickr_scraped/street_photography/downloaded_urls.json.
# Downloaded: image_