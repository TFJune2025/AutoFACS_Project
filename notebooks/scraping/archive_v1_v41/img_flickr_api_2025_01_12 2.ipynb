# %%
import requests
import os
import time
import json
from datetime import datetime
from dotenv import load_dotenv

# %%
# Persistent Tracking: Load previously downloaded URLs
def load_downloaded_urls(file_path="downloaded_urls_flickr.json"):
    if os.path.exists(file_path):
        try:
            with open(file_path, "r") as f:
                urls = set(json.load(f))
            print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
            return urls
        except json.JSONDecodeError:
            print(f"Warning: {file_path} is empty or corrupted. Initializing as empty.")
            return set()
    else:
        return set()

# %%
# Persistent Tracking: Save downloaded URLs
def save_downloaded_urls(downloaded_urls, file_path="/home/natalyagrokh/img_datasets/downloaded_urls_flickr.json"):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Generate queries related to people
def generate_people_related_queries():
    return ["faces", "smiling", "groups", "friends", "family", 
            "couples", "individuals", "emotions", "sad", "angry", "happy", "joyful",
            "suspicious", "disgust","fear", "rage","human faces","profession", "human", 
            "people", "portraits"]

# %%
# Download an image from a URL
def download_image(url, output_folder, filename):
    try:
        response = requests.get(url, stream=True, timeout=120)
        response.raise_for_status()
        file_path = os.path.join(output_folder, filename)
        with open(file_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {file_path}")
        return True
    except requests.exceptions.HTTPError as e:
        if response.status_code == 429:
            print(f"Rate limit exceeded for {url}. Retrying in 60 seconds...")
            time.sleep(60)
            return False  # Retry logic will occur in the main loop
        else:
            print(f"HTTP error for {url}: {e}")
            return False
    except Exception as e:
        print(f"Failed to download {url}: {e}")
        return False

# %%
# Fetch and save images from Flickr
def auto_flickr_images(api_key, queries, output_folder, batch_size=100, max_requests=3600, wait_time=3600):
    base_url = "https://www.flickr.com/services/rest/"
    method = "flickr.photos.search"

    os.makedirs(output_folder, exist_ok=True)
    api_call_count = 0
    downloaded_urls = load_downloaded_urls()

    # Ensure JSON file is created even if no downloads occur
    if not downloaded_urls:
        save_downloaded_urls(downloaded_urls)

    existing_files = [f for f in os.listdir(output_folder) if f.endswith(".jpg")]
    existing_numbers = [int(f.split("_")[1].split(".")[0]) for f in existing_files if "_" in f]
    start_index = max(existing_numbers) + 1 if existing_numbers else 1

    for query in queries:
        print(f"Starting query: {query}")
        total_downloaded = 0
        page = 1

        while api_call_count < max_requests:
            params = {
                "method": method,
                "api_key": api_key,
                "text": query,
                "format": "json",
                "nojsoncallback": 1,
                "per_page": batch_size,
                "page": page,
                "extras": "url_o,url_m"
            }

            try:
                response = requests.get(base_url, params=params)
                if response.status_code == 429:  # Handle Too Many Requests
                    print("Too many requests. Waiting for 60 seconds...")
                    time.sleep(60)
                    continue

                api_call_count += 1
                print(f"API Calls Made: {api_call_count}")

                if response.status_code != 200:
                    print(f"Error: {response.status_code} - {response.text}")
                    break

                data = response.json()
                photos = data.get("photos", {}).get("photo", [])

                if not photos:
                    print(f"No more photos available for query: {query}")
                    break

                for photo in photos:
                    photo_url = photo.get("url_o") or photo.get("url_m")
                    if not photo_url:
                        print(f"Skipping photo due to missing URL: {photo}")
                        continue

                    filename = f"image_{start_index + total_downloaded}.jpg"
                    if download_image(photo_url, output_folder, filename):
                        downloaded_urls.add(photo_url)
                        save_downloaded_urls(downloaded_urls)  # Save immediately after each download
                        total_downloaded += 1

                page += 1

                if api_call_count >= max_requests:
                    print("Max API requests reached for this hour.")
                    break

                time.sleep(1)  # Enforce 1 request per second

            except requests.exceptions.RequestException as e:
                print(f"Error fetching page {page}: {e}")

        print(f"Finished query: {query}")

        if api_call_count >= max_requests:
            print(f"Waiting {wait_time / 60} minutes before starting the next cycle...")
            time.sleep(wait_time)
            api_call_count = 0

    save_downloaded_urls(downloaded_urls)
    print(f"Process completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}.")

# %%
if __name__ == "__main__":
    # Load variables from .env
    load_dotenv()

    API_KEY = os.getenv("FLICKR_API_KEY") 
    
    if not API_KEY:
        raise ValueError("FLICKR_API_KEY not found in .env file")

    QUERIES = generate_people_related_queries()
    OUTPUT_FOLDER = "/home/natalyagrokh/img_datasets/flickr_contempt"
    
    auto_flickr_images(api_key=API_KEY, queries=QUERIES, output_folder=OUTPUT_FOLDER, batch_size=100, max_requests=3600, wait_time=3600)
# Out:
# Loaded 7164 previously downloaded URLs from downloaded_urls_flickr.json.
# Starting query: faces
# API Calls Made: 1
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43570.jpg
# Saved 7165 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43571.jpg
# Saved 7166 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43572.jpg
# Saved 7167 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43573.jpg
# Saved 7168 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43574.jpg
# Saved 7169 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43575.jpg
# Saved 7170 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43576.jpg
# Saved 7171 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43577.jpg
# Saved 7172 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43578.jpg
# Saved 7173 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43579.jpg
# Saved 7174 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43580.jpg
# Saved 7175 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43581.jpg
# Saved 7176 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43582.jpg
# Saved 7177 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43583.jpg
# Saved 7178 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43584.jpg
# Saved 7179 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43585.jpg
# Saved 7180 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43586.jpg
# Saved 7181 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43587.jpg
# Saved 7182 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43588.jpg
# Saved 7183 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43589.jpg
# Saved 7184 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43590.jpg
# Saved 7185 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43591.jpg
# Saved 7186 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43592.jpg
# Saved 7187 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43593.jpg
# Saved 7188 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43594.jpg
# Saved 7189 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43595.jpg
# Saved 7190 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43596.jpg
# Saved 7191 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43597.jpg
# Saved 7192 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43598.jpg
# Saved 7193 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43599.jpg
# Saved 7194 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43600.jpg
# Saved 7195 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43601.jpg
# Saved 7196 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43602.jpg
# Saved 7197 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43603.jpg
# Saved 7198 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43604.jpg
# Saved 7199 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43605.jpg
# Saved 7200 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43606.jpg
# Saved 7201 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43607.jpg
# Saved 7202 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43608.jpg
# Saved 7203 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43609.jpg
# Saved 7204 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43610.jpg
# Saved 7205 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43611.jpg
# Saved 7206 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43612.jpg
# Saved 7207 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43613.jpg
# Saved 7208 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43614.jpg
# Saved 7209 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43615.jpg
# Saved 7210 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43616.jpg
# Saved 7211 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43617.jpg
# Saved 7212 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43618.jpg
# Saved 7213 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43619.jpg
# Saved 7214 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43620.jpg
# Saved 7215 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43621.jpg
# Saved 7216 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43622.jpg
# Saved 7217 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43623.jpg
# Saved 7218 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43624.jpg
# Saved 7219 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43625.jpg
# Saved 7220 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43626.jpg
# Saved 7221 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43627.jpg
# Saved 7222 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43628.jpg
# Saved 7223 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43629.jpg
# Saved 7224 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43630.jpg
# Saved 7225 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43631.jpg
# Saved 7226 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43632.jpg
# Saved 7227 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43633.jpg
# Saved 7228 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43634.jpg
# Saved 7229 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43635.jpg
# Saved 7230 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43636.jpg
# Saved 7231 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43637.jpg
# Saved 7232 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43638.jpg
# Saved 7233 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43639.jpg
# Saved 7234 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43640.jpg
# Saved 7235 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43641.jpg
# Saved 7236 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43642.jpg
# Saved 7237 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43643.jpg
# Saved 7238 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43644.jpg
# Saved 7239 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43645.jpg
# Saved 7240 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43646.jpg
# Saved 7241 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43647.jpg
# Saved 7242 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43648.jpg
# Saved 7243 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43649.jpg
# Saved 7244 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43650.jpg
# Saved 7245 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43651.jpg
# Saved 7246 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43652.jpg
# Saved 7247 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43653.jpg
# Saved 7248 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43654.jpg
# Saved 7249 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43655.jpg
# Saved 7250 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43656.jpg
# Saved 7251 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43657.jpg
# Saved 7252 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43658.jpg
# Saved 7253 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43659.jpg
# Saved 7254 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43660.jpg
# Saved 7255 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43661.jpg
# Saved 7256 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43662.jpg
# Saved 7257 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43663.jpg
# Saved 7258 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43664.jpg
# Saved 7259 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43665.jpg
# Saved 7260 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43666.jpg
# Saved 7261 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43667.jpg
# Saved 7262 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43668.jpg
# Saved 7263 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43669.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# API Calls Made: 2
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43670.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43671.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43672.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43673.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43674.jpg
# Saved 7264 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43675.jpg
# Saved 7265 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43676.jpg
# Saved 7266 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43677.jpg
# Saved 7267 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43678.jpg
# Saved 7268 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43679.jpg
# Saved 7269 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43680.jpg
# Saved 7270 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43681.jpg
# Saved 7271 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43682.jpg
# Saved 7272 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43683.jpg
# Saved 7273 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 QUERIES = generate_people_related_queries()
#       5 OUTPUT_FOLDER = "/home/natalyagrokh/img_datasets/flickr_images"
# ----> 7 auto_flickr_images(api_key=API_KEY, queries=QUERIES, output_folder=OUTPUT_FOLDER, batch_size=100, max_requests=3600, wait_time=3600)
#
# Cell In[6], line 63, in auto_flickr_images(api_key, queries, output_folder, batch_size, max_requests, wait_time)
#      60     continue
#      62 filename = f"image_{start_index + total_downloaded}.jpg"
# ---> 63 if download_image(photo_url, output_folder, filename):
#      64     downloaded_urls.add(photo_url)
#      65     save_downloaded_urls(downloaded_urls)  # Save immediately after each download
#
# Cell In[5], line 4, in download_image(url, output_folder, filename)
#       2 def download_image(url, output_folder, filename):
#       3     try:
# ----> 4         response = requests.get(url, stream=True, timeout=120)
#       5         response.raise_for_status()
#       6         file_path = os.path.join(output_folder, filename)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:
