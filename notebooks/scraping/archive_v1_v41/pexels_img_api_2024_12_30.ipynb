# %%
import requests
import os
from PIL import Image
from io import BytesIO
from datetime import datetime
from dotenv import load_dotenv
import time
import json

# %%
# Directory to save downloaded pexels images
SAVE_DIR = "/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
# Load variables from .env
load_dotenv()

#set your Pexels API key
PEXELS_API_URL = "https://api.pexels.com/v1/search"

PEXELS_API_KEY = os.getenv("PEXELS_API_KEY")

if not PEXELS_API_KEY:
    raise ValueError("PEXELS_API_KEY not found in .env file")

# %%
# Persistent Tracking: Load previously downloaded URLs
def load_downloaded_urls(file_path="/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/downloaded_urls_pexels.json"):
    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            urls = set(json.load(f))
        print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
        return urls
    else:
        return set()

# %%
# Persistent Tracking: Save downloaded URLs
def save_downloaded_urls(downloaded_urls, file_path="/Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/downloaded_urls_pexels.json"):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Function to download and save images from Pexels
# max_batches=200,  == set based on a 200/hr api call max policy by pexels
# batch_size=80 == set on a max 80 imgs / api call policy
# wait_time=3600 == set to automate hourly calls
def auto_pexels_images(query, max_batches=200, batch_size=80, wait_time=3600):
    """
    Automatically fetch and save images from Pexels in batches, respecting API quotas.

    Args:
        query (str): Search query for images (e.g., "people's faces").
        max_batches (int): Maximum number of batches to fetch per run.
        batch_size (int): Number of images per batch.
        wait_time (int): Time to wait between full runs, in seconds.
    """
    MAX_RETRIES = 3  # Number of retries for a failed download
    api_call_count = 0  # Initialize API call counter

    while True:
        # Load previously downloaded URLs
        downloaded_urls = load_downloaded_urls()

        # Check existing images to determine the starting index
        existing_files = [f for f in os.listdir(SAVE_DIR) if f.startswith("image_") and f.endswith(".jpg")]
        existing_numbers = [int(f.split("_")[1].split(".")[0]) for f in existing_files if f.split("_")[1].split(".")[0].isdigit()]
        start_index = max(existing_numbers) + 1 if existing_numbers else 1

        total_downloaded = 0
        page = 1

        while total_downloaded < max_batches * batch_size:
            headers = {"Authorization": PEXELS_API_KEY}
            params = {
                "query": query, 
                "per_page": batch_size, 
                "page": page
            }

            response = requests.get(PEXELS_API_URL, headers=headers, params=params)
            api_call_count += 1  # Increment API call counter
            print(f"API Calls Made: {api_call_count}")

            if response.status_code == 429:  # Handle rate limiting (Too Many Requests)
                print("Rate limit reached. Waiting for 60 seconds before retrying...")
                time.sleep(60)  # Wait for 60 seconds before retrying
                continue  # Retry the same request

            if response.status_code != 200:
                print(f"Error: {response.status_code} - {response.text}")
                break

            data = response.json()
            photos = data.get("photos", [])

            if not photos:
                print("No more photos available.")
                break

            for photo in photos:
                image_url = photo["src"]["original"]

                if image_url in downloaded_urls:
                    print(f"Skipped duplicate URL: {image_url}")
                    continue

                for attempt in range(MAX_RETRIES):
                    try:
                        response = requests.get(image_url, timeout=120)
                        if response.status_code == 200:
                            file_name = os.path.join(SAVE_DIR, f"image_{start_index + total_downloaded}.jpg")
                            with open(file_name, "wb") as f:
                                f.write(response.content)
                            print(f"Downloaded: {file_name}")

                            downloaded_urls.add(image_url)
                            total_downloaded += 1
                            break
                    except (requests.ConnectionError, requests.Timeout) as e:
                        print(f"Attempt {attempt + 1} failed for {image_url}: {e}")
                        if attempt == MAX_RETRIES - 1:
                            print(f"Failed to download after {MAX_RETRIES} attempts: {image_url}")
                            with open("failed_urls.log", "a") as log_file:
                                log_file.write(image_url + "\n")

            page += 1  # Move to the next page

            if total_downloaded >= max_batches * batch_size:
                break

        # Save updated downloaded URLs
        save_downloaded_urls(downloaded_urls)

        print(f"Total images downloaded: {total_downloaded}")
        print(f"Process completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}.")

        # Wait before the next full run
        print(f"Waiting for {wait_time / 60} minutes before the next run...")
        time.sleep(wait_time)

# %%
# Call the function with desired search query
auto_pexels_images(query="Disgust+Emotion+Face", max_batches=200, batch_size=80, wait_time=3600)
# Out:
# Loaded 1 previously downloaded URLs from /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/downloaded_urls_pexels.json.
# API Calls Made: 1
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_1.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_2.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_3.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_4.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_5.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_6.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_7.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_8.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_9.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_10.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_11.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_12.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_13.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_14.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_15.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_16.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_17.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_18.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_19.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_20.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_21.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_22.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_23.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_24.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_25.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_26.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_27.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_28.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_29.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_30.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_31.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_32.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_33.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_34.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_35.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_36.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_37.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_38.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_39.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_40.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_41.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_42.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_43.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_44.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_45.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_46.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_47.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_48.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_49.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_50.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_51.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_52.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_53.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_54.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_55.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_56.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_57.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_58.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_59.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_60.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_61.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_62.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_63.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_64.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_65.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_66.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_67.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_68.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_69.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_70.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_71.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_72.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_73.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_74.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_75.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_76.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_77.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_78.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_79.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_80.jpg
# API Calls Made: 2
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_81.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_82.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_83.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_84.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_85.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_86.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_87.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_88.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_89.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_90.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_91.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_92.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_93.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_94.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_95.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_96.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_97.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_98.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_99.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_100.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_101.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_102.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_103.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_104.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_105.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_106.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_107.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_108.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_109.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_110.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_111.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_112.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_113.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_114.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_115.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_116.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_117.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_118.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_119.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_120.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_121.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_122.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_123.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_124.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_125.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_126.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_127.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_128.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_129.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_130.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_131.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_132.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_133.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_134.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_135.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_136.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_137.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_138.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_139.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_140.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_141.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_142.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_143.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_144.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_145.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_146.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_147.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_148.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_149.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_150.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_151.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_152.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_153.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_154.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_155.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_156.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_157.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_158.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_159.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_160.jpg
# API Calls Made: 3
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_161.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_162.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_163.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_164.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_165.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_166.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_167.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_168.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_169.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_170.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_171.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_172.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_173.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_174.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_175.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_176.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_177.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_178.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_179.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_180.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_181.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_182.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_183.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_184.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_185.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_186.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_187.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_188.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_189.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_190.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_191.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_192.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_193.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_194.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_195.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_196.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_197.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_198.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_199.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_200.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_201.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_202.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_203.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_204.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_205.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_206.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_207.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_208.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_209.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_210.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_211.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_212.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_213.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_214.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_215.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_216.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_217.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_218.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_219.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_220.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_221.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_222.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_223.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_224.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_225.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_226.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_227.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_228.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_229.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_230.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_231.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_232.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_233.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_234.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_235.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_236.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_237.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_238.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_239.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_240.jpg
# API Calls Made: 4
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_241.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_242.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_243.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_244.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_245.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_246.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_247.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_248.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_249.jpg
# Downloaded: /Volumes/JavaAOT/Documents/AI/ml_expressions/img_datasets/pexels_disgust/image_250.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Call the function with desired search query
# ----> 2 auto_pexels_images(query="Disgust+Emotion+Face", max_batches=200, batch_size=80, wait_time=3600)
#
# Cell In[6], line 67, in auto_pexels_images(query, max_batches, batch_size, wait_time)
#      65 for attempt in range(MAX_RETRIES):
#      66     try:
# ---> 67         response = requests.get(image_url, timeout=120)
#      68         if response.status_code == 200:
#      69             file_name = os.path.join(SAVE_DIR, f"image_{start_index + total_downloaded}.jpg")
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 # Trigger any extra validation we need to do.
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     407     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:1061, in HTTPSConnectionPool._validate_conn(self, conn)
#    1059 # Force connect early to allow us to validate the connection.
#    1060 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1061     conn.connect()
#    1063 if not conn.is_verified:
#    1064     warnings.warn(
#    1065         (
#    1066             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1071         InsecureRequestWarning,
#    1072     )
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):  # Defensive:
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/util/ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     446     warnings.warn(
#     447         "An HTTPS request has been made, but the SNI (Server Name "
#     448         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     454         SNIMissingWarning,
#     455     )
#     457 if send_sni:
# --> 458     ssl_sock = _ssl_wrap_socket_impl(
#     459         sock, context, tls_in_tls, server_hostname=server_hostname
#     460     )
#     461 else:
#     462     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/site-packages/urllib3/util/ssl_.py:502, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     499     return SSLTransport(sock, ssl_context, server_hostname)
#     501 if server_hostname:
# --> 502     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     503 else:
#     504     return ssl_context.wrap_socket(sock)
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/ssl.py:1074, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1071         if timeout == 0.0:
#    1072             # non-blocking
#    1073             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1074         self.do_handshake()
#    1075 except (OSError, ValueError):
#    1076     self.close()
#
# File /opt/anaconda3/envs/ml_expressions/lib/python3.9/ssl.py:1343, in SSLSocket.do_handshake(self, block)
#    1341     if timeout == 0.0 and block:
#    1342         self.settimeout(None)
# -> 1343     self._sslobj.do_handshake()
#    1344 finally:
#    1345     self.settimeout(timeout)
#
# KeyboardInterrupt:
