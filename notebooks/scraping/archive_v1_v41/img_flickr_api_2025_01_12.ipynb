# %%
import requests
import os
import time
import json
from datetime import datetime
from dotenv import load_dotenv

# %%
# Persistent Tracking: Load previously downloaded URLs
def load_downloaded_urls(file_path="downloaded_urls_flickr.json"):
    if os.path.exists(file_path):
        try:
            with open(file_path, "r") as f:
                urls = set(json.load(f))
            print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
            return urls
        except json.JSONDecodeError:
            print(f"Warning: {file_path} is empty or corrupted. Initializing as empty.")
            return set()
    else:
        return set()

# %%
# Persistent Tracking: Save downloaded URLs
def save_downloaded_urls(downloaded_urls, file_path="/home/natalyagrokh/img_datasets/downloaded_urls_flickr.json"):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Generate queries related to people
def generate_people_related_queries():
    return ["contempt"] 
    # "faces", "smiling", "groups", "friends", "family", 
    #         "couples", "individuals", "emotions", "sad", "angry", "happy", "joyful",
    #         "suspicious", "disgust","fear", "rage","human faces","profession", "human", 
    #         "people", "portraits"]

# %%
# Download an image from a URL
def download_image(url, output_folder, filename):
    try:
        response = requests.get(url, stream=True, timeout=120)
        response.raise_for_status()
        file_path = os.path.join(output_folder, filename)
        with open(file_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {file_path}")
        return True
    except requests.exceptions.HTTPError as e:
        if response.status_code == 429:
            print(f"Rate limit exceeded for {url}. Retrying in 60 seconds...")
            time.sleep(60)
            return False  # Retry logic will occur in the main loop
        else:
            print(f"HTTP error for {url}: {e}")
            return False
    except Exception as e:
        print(f"Failed to download {url}: {e}")
        return False

# %%
# Fetch and save images from Flickr
def auto_flickr_images(api_key, queries, output_folder, batch_size=100, max_requests=3600, wait_time=3600):
    base_url = "https://www.flickr.com/services/rest/"
    method = "flickr.photos.search"

    os.makedirs(output_folder, exist_ok=True)
    api_call_count = 0
    downloaded_urls = load_downloaded_urls()

    # Ensure JSON file is created even if no downloads occur
    if not downloaded_urls:
        save_downloaded_urls(downloaded_urls)

    existing_files = [f for f in os.listdir(output_folder) if f.endswith(".jpg")]
    existing_numbers = [int(f.split("_")[1].split(".")[0]) for f in existing_files if "_" in f]
    start_index = max(existing_numbers) + 1 if existing_numbers else 1

    for query in queries:
        print(f"Starting query: {query}")
        total_downloaded = 0
        page = 1

        while api_call_count < max_requests:
            params = {
                "method": method,
                "api_key": api_key,
                "text": query,
                "format": "json",
                "nojsoncallback": 1,
                "per_page": batch_size,
                "page": page,
                "extras": "url_o,url_m"
            }

            try:
                response = requests.get(base_url, params=params)
                if response.status_code == 429:  # Handle Too Many Requests
                    print("Too many requests. Waiting for 60 seconds...")
                    time.sleep(60)
                    continue

                api_call_count += 1
                print(f"API Calls Made: {api_call_count}")

                if response.status_code != 200:
                    print(f"Error: {response.status_code} - {response.text}")
                    break

                data = response.json()
                photos = data.get("photos", {}).get("photo", [])

                if not photos:
                    print(f"No more photos available for query: {query}")
                    break

                for photo in photos:
                    photo_url = photo.get("url_o") or photo.get("url_m")
                    if not photo_url:
                        print(f"Skipping photo due to missing URL: {photo}")
                        continue

                    filename = f"image_{start_index + total_downloaded}.jpg"
                    if download_image(photo_url, output_folder, filename):
                        downloaded_urls.add(photo_url)
                        save_downloaded_urls(downloaded_urls)  # Save immediately after each download
                        total_downloaded += 1

                page += 1

                if api_call_count >= max_requests:
                    print("Max API requests reached for this hour.")
                    break

                time.sleep(1)  # Enforce 1 request per second

            except requests.exceptions.RequestException as e:
                print(f"Error fetching page {page}: {e}")

        print(f"Finished query: {query}")

        if api_call_count >= max_requests:
            print(f"Waiting {wait_time / 60} minutes before starting the next cycle...")
            time.sleep(wait_time)
            api_call_count = 0

    save_downloaded_urls(downloaded_urls)
    print(f"Process completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}.")

# %%
# Example Usage
if __name__ == "__main__":
    # Load variables from .env
    load_dotenv()

    API_KEY = os.getenv("FLICKR_API_KEY") 
    
    if not API_KEY:
        raise ValueError("FLICKR_API_KEY not found in .env file")
    
    QUERIES = generate_people_related_queries()
    OUTPUT_FOLDER = "/home/natalyagrokh/img_datasets/flickr_contempt"

    auto_flickr_images(api_key=API_KEY, queries=QUERIES, output_folder=OUTPUT_FOLDER, batch_size=100, max_requests=3600, wait_time=3600)
# Out:
# Saved 0 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Starting query: contempt
# API Calls Made: 1
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_1.jpg
# Saved 1 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_2.jpg
# Saved 2 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_3.jpg
# Saved 3 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_4.jpg
# Saved 4 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_5.jpg
# Saved 5 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_6.jpg
# Saved 6 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_7.jpg
# Saved 7 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_8.jpg
# Saved 8 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_9.jpg
# Saved 9 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_10.jpg
# Saved 10 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_11.jpg
# Saved 11 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_12.jpg
# Saved 12 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_13.jpg
# Saved 13 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_14.jpg
# Saved 14 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_15.jpg
# Saved 15 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_16.jpg
# Saved 16 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_17.jpg
# Saved 17 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_18.jpg
# Saved 18 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_19.jpg
# Saved 19 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_20.jpg
# Saved 20 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_21.jpg
# Saved 21 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_22.jpg
# Saved 22 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_23.jpg
# Saved 23 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_24.jpg
# Saved 24 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_25.jpg
# Saved 25 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_26.jpg
# Saved 26 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_27.jpg
# Saved 27 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_28.jpg
# Saved 28 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_29.jpg
# Saved 29 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_30.jpg
# Saved 30 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_31.jpg
# Saved 31 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_32.jpg
# Saved 32 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_33.jpg
# Saved 33 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_34.jpg
# Saved 34 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_35.jpg
# Saved 35 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_36.jpg
# Saved 36 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_37.jpg
# Saved 37 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_38.jpg
# Saved 38 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_39.jpg
# Saved 39 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_40.jpg
# Saved 40 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_41.jpg
# Saved 41 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_42.jpg
# Saved 42 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_43.jpg
# Saved 43 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_44.jpg
# Saved 44 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_45.jpg
# Saved 45 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_46.jpg
# Saved 46 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_47.jpg
# Saved 47 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_48.jpg
# Saved 48 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_49.jpg
# Saved 49 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_50.jpg
# Saved 50 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_51.jpg
# Saved 51 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image
downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_422.jpg
# Saved 421 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_423.jpg
# Saved 422 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_424.jpg
# Saved 423 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_425.jpg
# Saved 424 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_426.jpg
# Saved 425 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_427.jpg
# Saved 426 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_428.jpg
# Saved 427 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_429.jpg
# Saved 428 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_430.jpg
# Saved 429 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_431.jpg
# Saved 430 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_432.jpg
# Saved 431 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_433.jpg
# Saved 432 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_434.jpg
# Saved 433 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_435.jpg
# Saved 434 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_436.jpg
# Saved 435 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_437.jpg
# Saved 436 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_438.jpg
# Saved 437 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_439.jpg
# Saved 438 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_440.jpg
# Saved 439 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_441.jpg
# Saved 440 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_442.jpg
# Saved 441 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_443.jpg
# Saved 442 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_444.jpg
# Saved 443 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_445.jpg
# Saved 444 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_446.jpg
# Saved 445 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_447.jpg
# Saved 446 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_448.jpg
# Saved 447 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_449.jpg
# Saved 448 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_450.jpg
# Saved 449 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_451.jpg
# Saved 450 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_452.jpg
# Saved 451 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_453.jpg
# Saved 452 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_454.jpg
# Saved 453 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_455.jpg
# Saved 454 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_456.jpg
# Saved 455 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_457.jpg
# Saved 456 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_458.jpg
# Saved 457 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_459.jpg
# Saved 458 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_460.jpg
# Saved 459 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_461.jpg
# Saved 460 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_462.jpg
# Saved 461 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Rate limit exceeded for https://live.staticflickr.com/65535/53248781110_5063eb3eaa.jpg. Retrying in 60 seconds...
# Rate limit exceeded for https://live.staticflickr.com/65535/53248644414_2f727a3b02.jpg. Retrying in 60 seconds...
# Downloaded: /home/natalyagrokh/img_datasets/flickr_images/image_463.jpg
# Saved 462 downloaded URLs to /home/natalyagrokh/img_datasets/downloaded_urls_flickr.json.
# Rate limit exceeded for https://live.staticflickr.com/65535/53247405682_2266f228c1.jpg. Retrying in 60 seconds...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 5, in download_image(url, output_folder, filename)
#       4 response = requests.get(url, stream=True, timeout=120)
# ----> 5 response.raise_for_status()
#       6 file_path = os.path.join(output_folder, filename)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://live.staticflickr.com/65535/53247405682_2266f228c1.jpg
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 QUERIES = generate_people_related_queries()
#       5 OUTPUT_FOLDER = "/home/natalyagrokh/img_datasets/flickr_images"
# ----> 7 auto_flickr_images(api_key=API_KEY, queries=QUERIES, output_folder=OUTPUT_FOLDER, batch_size=100, max_requests=3600, wait_time=3600)
#
# Cell In[6], line 63, in auto_flickr_images(api_key, queries, output_folder, batch_size, max_requests, wait_time)
#      60     continue
#      62 filename = f"image_{start_index + total_downloaded}.jpg"
# ---> 63 if download_image(photo_url, output_folder, filename):
#      64     downloaded_urls.add(photo_url)
#      65     save_downloaded_urls(downloaded_urls)  # Save immediately after each download
#
# Cell In[5], line 15, in download_image(url, output_folder, filename)
#      13 if response.status_code == 429:
#      14     print(f"Rate limit exceeded for {url}. Retrying in 60 seconds...")
# ---> 15     time.sleep(60)
#      16     return False  # Retry logic will occur in the main loop
#      17 else:
#
# KeyboardInterrupt:
