# %%
import requests
import os
import time

# %%
def scrape_faces_in_news(query_list, output_dir, max_results=10, delay=5):
    """
    Scrapes Wikimedia Commons for images based on a list of search queries.

    Args:
        query_list (list): List of search queries (e.g., ["face AND news", "portrait AND news"]).
        output_dir (str): Directory to save the images.
        max_results (int): Maximum number of images to download per query.
        delay (int): Delay (in seconds) between API calls to avoid rate limits.
    """
    base_url = "https://commons.wikimedia.org/w/api.php"

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Loop through each search query
    for query in query_list:
        print(f"\nSearching for: '{query}'\n" + "-" * 40)
        query_exhausted = False  # Flag to detect when no more results are found

        # Step 1: Search for images
        search_params = {
            "action": "query",
            "format": "json",
            "list": "search",
            "srsearch": query,
            "srnamespace": 6,  # Media files only
            "srlimit": max_results  # Limit the number of results
        }
        response = requests.get(base_url, params=search_params)
        search_results = response.json().get('query', {}).get('search', [])

        if not search_results:
            print(f"No more images found for query: '{query}'. Moving to the next query.\n")
            continue  # Skip to the next query if no results are found

        # Step 2: Download each image
        for result in search_results:
            title = result['title']  # e.g., "File:Example.jpg"
            
            # Get image information (URL and metadata)
            image_info_params = {
                "action": "query",
                "format": "json",
                "titles": title,
                "prop": "imageinfo",
                "iiprop": "url|extmetadata|size"  # Fetch image URLs and metadata
            }
            image_info_response = requests.get(base_url, params=image_info_params)
            pages = image_info_response.json().get('query', {}).get('pages', {})

            for page_id, page_data in pages.items():
                if "imageinfo" in page_data:
                    image_url = page_data["imageinfo"][0]["url"]
                    ext_metadata = page_data["imageinfo"][0].get("extmetadata", {})
                    license_info = ext_metadata.get("LicenseShortName", {}).get("value", "Unknown License")

                    # Step 3: Download the image
                    image_data = requests.get(image_url).content
                    file_name = os.path.join(output_dir, title.replace("File:", "").replace(" ", "_"))

                    with open(file_name, 'wb') as file:
                        file.write(image_data)
                        print(f"Downloaded: {file_name} (License: {license_info})")

                    # Delay to avoid rate-limiting
                    time.sleep(delay)

        # Flagging query as exhausted
        if len(search_results) < max_results:
            print(f"No more results for query: '{query}'.\n")
            query_exhausted = True

        # Log completion of the current query
        if not query_exhausted:
            print(f"Finished processing all available images for query: '{query}'.\n")

    print("Scraping and downloading completed for all queries.")

# %%
# Example usage
query_combinations = [
    "face AND news",
    "portrait AND journalist",
    "headshot AND news",
    "reporter AND face",
    "journalist portrait"
]

scrape_faces_in_news(
    query_list=query_combinations,
    output_dir="home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images",
    max_results=10,  # Limit to 10 images per query
    delay=5  # 5 seconds between requests
)
# Out:
# Searching for: 'face AND news'
# ----------------------------------------
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Boy_Face_from_Venezuela.jpg (License: CC0)
# Exception ignored in: <finalize object at 0x7f7c814a9ba0; dead>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ml_expressions/lib/python3.9/weakref.py", line 591, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py", line 1176, in _close_pool_connections
#     conn.close()
#   File "/opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connection.py", line 322, in close
#     super().close()
# KeyboardInterrupt:
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Dustin_Brown_14,_2015_Wimbledon_Qualifying_-_Diliff.jpg (License: CC BY 3.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Covid-19_San_Salvatore_04.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Covid-19_San_Salvatore_16.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Self_traditional_folk_face_painting_(2).jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/London_Big_Ben_Inner_Clock_Face_1070925-PSD.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Avahi_5_face_noir.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Face_tele-club.jpg (License: CC BY 3.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Algérie_-_Arménie_-_20140531_-_Yacine_Brahimi_(Alg)_face_à_Taron_Voskanyan_(Arm).jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Face_Recognition_Field_Test_at_Südkreuz_12.jpg (License: CC BY-SA 4.0)
# Finished processing all available images for query: 'face AND news'.
#
#
# Searching for: 'portrait AND journalist'
# ----------------------------------------
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Fredi-Gruber-960x640.jpg (License: CC0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/José_Jasán_Nieves_Cárdenas.jpg (License: CC BY 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Elaine_Díaz_Rodríguez.jpg (License: CC BY 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Hans_Forster.jpg (License: CC0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Étienne_Carjat,_Portrait_of_Charles_Baudelaire,_circa_1862.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Violet_McNaughton_SPL_-_LHR,_Don_Kerr_Collection,_MG_169,_VII_History_D_1).jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/میلاد_علوی.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Marcio_Delgado_-_Journalist.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Portrait_of_Billie_Holiday_and_Mister,_Downbeat,_New_York,_N.Y.,_ca._Feb._1947_(LOC,_5020400274,_cropped).jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Frances_Benjamin_Johnston,_Self-Portrait_(as_"New_Woman"),_1896.jpg (License: Public domain)
# Finished processing all available images for query: 'portrait AND journalist'.
#
#
# Searching for: 'headshot AND news'
# ----------------------------------------
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Alan_Bates_vintage_headshot_from_"The_Entertainer"_(1960).jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Leah+Elson+Headshot+2022+(2).jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Melvyn_Douglas_in_the_1930s_-_press_photograph.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Byron_Trott_Headshot.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Burl_Ives_-_Cat_on_a_Hot_Tin_Roof_(1958_press_photo).png (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Celine_Tricart_headshot.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Female_impala_headshot.jpg (License: GFDL 1.2)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Male_impala_headshot.jpg (License: GFDL 1.2)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Updated-hs-zameer-rizvi-headshot-1.jpg (License: CC BY 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Edmond_O'Brien,_The_Star_&_the_Story_-_"Dark_Stranger"_(TV,_1955).png (License: Public domain)
# Finished processing all available images for query: 'headshot AND news'.
#
#
# Searching for: 'reporter AND face'
# ----------------------------------------
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/IosipenkoOlga.png (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Claude_Askolovitch.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Reverse_side_of_"Valley_of_the_Sun"_(1942)_photo_with_brief_synopsis_of_scene.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/South_Asian_Journal_of_Geriatric_Medicine,_Surgery,_Palliative_Care_&_Hospice_-_Dr._Abhishek_Shukla_MD_FRCP_Palliative_care_Specialist.jpg (License: CC0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Dominique_Bourg_en_dédicace_à_l'issue_d'une_conférence_au_collège_Sabine_Zlatin_à_Belley_en_novembre_2019.jpg (License: CC0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Portrait_of_William_Lane_1890-1894_slnsw_pxa_1023.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Art_Tatum,_Vogue_Room_1948_(Gottlieb).jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Lange-MigrantMother02.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Kerényi_György_(journalist).jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Farmer_walking_in_dust_storm_Cimarron_County_Oklahoma2.jpg (License: Public domain)
# Finished processing all available images for query: 'reporter AND face'.
#
#
# Searching for: 'journalist portrait'
# ----------------------------------------
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Photo_Portrait_of_the_Brazilian_journalist_Victor_Civita_1969_-_Touring_Club_Italiano_11_5260.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Val_Hennessy,_journalist,_portrait_by_Phyllis_Dupuy.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Journalist_Jela_Krecic_portrait_by_Voranc_Vogel.jpg (License: CC BY-SA 3.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Photo_Portrait_of_the_Italian_writer_and_journalist_Maffio_Maffii_1956_-_Touring_Club_Italiano_11_5391.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Louis_Tytgadt_-_Portrait_of_the_Politician_and_Journalist_Willem_Rogghé_-_1915-G_-_Museum_of_Fine_Arts_Ghent_(MSK).jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Photo_Portrait_of_the_Italian_writer_and_journalist_Guido_Lopez_1958_-_Touring_Club_Italiano_11_5388.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Étienne_Carjat,_Portrait_of_Charles_Baudelaire,_circa_1862.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Portrait_of_T.P._Gill,_Journalist_P5284.jpg (License: Public domain)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Photo_Portrait_of_Italian_painter,_politician,_and_journalist_Vittorio_Meoni_1920_-_Touring_Club_Italiano_11_5407.jpg (License: CC BY-SA 4.0)
# Downloaded: home/natalyagrokh/img_datasets/temp_scraped_images/wikimedia_images/Woman_TV_journalist_profile_(10419459254).jpg (License: CC BY 2.0)
# Finished processing all available images for query: 'journalist portrait'.
#
# Scraping and downloading completed for all queries.
