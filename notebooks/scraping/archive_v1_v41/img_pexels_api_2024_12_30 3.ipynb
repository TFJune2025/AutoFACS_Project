# %%
import requests
import os
from PIL import Image
from io import BytesIO
from datetime import datetime
from dotenv import load_dotenv
import time
import json

# %%
# Directory to save downloaded pexels images
SAVE_DIR = "/home/natalyagrokh/img_datasets/pexels_contempt"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
#set your Pexels credentials

# Load variables from .env
load_dotenv()

PEXELS_API_KEY = os.getenv("PEXELS_API_KEY")

if not PEXELS_API_KEY:
    raise ValueError("PEXELS_API_KEY not found in .env file")

PEXELS_API_URL = "https://api.pexels.com/v1/search"

# %%
# Persistent Tracking: Load previously downloaded URLs
def load_downloaded_urls(file_path="/home/natalyagrokh/img_datasets/downloaded_urls_pexels.json"):
    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            urls = set(json.load(f))
        print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
        return urls
    else:
        return set()

# %%
# Persistent Tracking: Save downloaded URLs
def save_downloaded_urls(downloaded_urls, file_path="/home/natalyagrokh/img_datasets/downloaded_urls_pexels.json"):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Function to download and save images from Pexels
# max_batches=200,  == set based on a 200/hr api call max policy by pexels
# batch_size=80 == set on a max 80 imgs / api call policy
# wait_time=3600 == set to automate hourly calls
def auto_pexels_images(query, max_batches=200, batch_size=80, wait_time=3600):
    """
    Automatically fetch and save images from Pexels in batches, respecting API quotas.

    Args:
        query (str): Search query for images (e.g., "people's faces").
        max_batches (int): Maximum number of batches to fetch per run.
        batch_size (int): Number of images per batch.
        wait_time (int): Time to wait between full runs, in seconds.
    """
    MAX_RETRIES = 3  # Number of retries for a failed download
    api_call_count = 0  # Initialize API call counter

    while True:
        # Load previously downloaded URLs
        downloaded_urls = load_downloaded_urls()

        # Check existing images to determine the starting index
        existing_files = [f for f in os.listdir(SAVE_DIR) if f.startswith("image_") and f.endswith(".jpg")]
        existing_numbers = [int(f.split("_")[1].split(".")[0]) for f in existing_files if f.split("_")[1].split(".")[0].isdigit()]
        start_index = max(existing_numbers) + 1 if existing_numbers else 1

        total_downloaded = 0
        page = 1

        while total_downloaded < max_batches * batch_size:
            headers = {"Authorization": PEXELS_API_KEY}
            params = {
                "query": query, 
                "per_page": batch_size, 
                "page": page
            }

            response = requests.get(PEXELS_API_URL, headers=headers, params=params)
            api_call_count += 1  # Increment API call counter
            print(f"API Calls Made: {api_call_count}")

            if response.status_code == 429:  # Handle rate limiting (Too Many Requests)
                print("Rate limit reached. Waiting for 60 seconds before retrying...")
                time.sleep(60)  # Wait for 60 seconds before retrying
                continue  # Retry the same request

            if response.status_code != 200:
                print(f"Error: {response.status_code} - {response.text}")
                break

            data = response.json()
            photos = data.get("photos", [])

            if not photos:
                print("No more photos available.")
                break

            for photo in photos:
                image_url = photo["src"]["original"]

                if image_url in downloaded_urls:
                    print(f"Skipped duplicate URL: {image_url}")
                    continue

                for attempt in range(MAX_RETRIES):
                    try:
                        response = requests.get(image_url, timeout=120)
                        if response.status_code == 200:
                            file_name = os.path.join(SAVE_DIR, f"image_{start_index + total_downloaded}.jpg")
                            with open(file_name, "wb") as f:
                                f.write(response.content)
                            print(f"Downloaded: {file_name}")

                            downloaded_urls.add(image_url)
                            total_downloaded += 1
                            break
                    except (requests.ConnectionError, requests.Timeout) as e:
                        print(f"Attempt {attempt + 1} failed for {image_url}: {e}")
                        if attempt == MAX_RETRIES - 1:
                            print(f"Failed to download after {MAX_RETRIES} attempts: {image_url}")
                            with open("failed_urls.log", "a") as log_file:
                                log_file.write(image_url + "\n")

            page += 1  # Move to the next page

            if total_downloaded >= max_batches * batch_size:
                break

        # Save updated downloaded URLs
        save_downloaded_urls(downloaded_urls)

        print(f"Total images downloaded: {total_downloaded}")
        print(f"Process completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}.")

        # Wait before the next full run
        print(f"Waiting for {wait_time / 60} minutes before the next run...")
        time.sleep(wait_time)

# %%
# Call the function with desired search query
auto_pexels_images(query="Contempt+Emotion+Face", max_batches=200, batch_size=80, wait_time=3600)
# Out:
# Loaded 1 previously downloaded URLs from /home/natalyagrokh/img_datasets/downloaded_urls_pexels.json.
# API Calls Made: 1
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_242.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_243.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_244.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_245.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_246.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_247.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_248.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_249.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_250.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_251.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_252.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_253.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_254.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_255.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_256.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_257.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_258.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_259.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_260.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_261.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_262.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_263.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_264.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_265.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_266.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_267.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_268.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_269.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_270.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_271.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_272.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_273.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_274.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_275.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_276.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_277.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_278.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_279.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_280.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_281.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_282.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_283.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_284.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_285.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_286.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_287.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_288.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_289.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_290.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_291.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_292.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_293.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_294.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_295.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_296.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_297.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_298.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_299.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_300.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_301.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_302.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_303.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_304.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_305.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_306.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_307.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_308.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_309.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_310.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_311.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_312.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_313.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_314.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_315.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_316.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_317.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_318.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_319.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_320.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_321.jpg
# API Calls Made: 2
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_322.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_323.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_324.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_325.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_326.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_327.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_328.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_329.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_330.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_331.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_332.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_333.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_334.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_335.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_336.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_337.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_338.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_339.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_340.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_341.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_342.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_343.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_344.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_345.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_346.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_347.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_348.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_349.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_350.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_351.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_352.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_353.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_354.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_355.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_356.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_357.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_358.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_359.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_360.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_361.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_362.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_363.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_364.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_365.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_366.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_367.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_368.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_369.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_370.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_371.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_372.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_373.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_374.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_375.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_376.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_377.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_378.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_379.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_380.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_381.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_382.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_383.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_384.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_385.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_386.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_387.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_388.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_389.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_390.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_391.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_392.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_393.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_394.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_395.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_396.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_397.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_398.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_399.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_400.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_401.jpg
# API Calls Made: 3
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_402.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_403.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_404.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_405.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_406.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_407.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_408.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_409.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_410.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_411.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_412.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_413.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_414.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_415.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_416.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_417.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_418.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_419.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_420.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_421.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_422.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_423.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_424.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_425.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_426.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_427.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_428.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_429.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_430.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_431.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_432.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_433.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_434.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_435.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_436.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_437.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_438.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_439.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_440.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_441.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_442.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_443.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_444.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_445.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_446.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_447.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_448.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_449.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_450.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_451.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_452.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_453.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_454.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_455.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_456.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_457.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_458.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_459.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_460.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_461.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_462.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_463.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_464.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_465.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_466.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_467.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_468.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_469.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_470.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_471.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_472.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_473.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_474.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_475.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_476.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_477.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_478.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_479.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_480.jpg
# Downloaded: /home/natalyagrokh/img_datasets/pexels_contempt/image_481.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Call the function with desired search query
# ----> 2 auto_pexels_images(query="Contempt+Emotion+Face", max_batches=200, batch_size=80, wait_time=3600)
#
# Cell In[6], line 38, in auto_pexels_images(query, max_batches, batch_size, wait_time)
#      31 headers = {"Authorization": PEXELS_API_KEY}
#      32 params = {
#      33     "query": query,
#      34     "per_page": batch_size,
#      35     "page": page
#      36 }
# ---> 38 response = requests.get(PEXELS_API_URL, headers=headers, params=params)
#      39 api_call_count += 1  # Increment API call counter
#      40 print(f"API Calls Made: {api_call_count}")
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/envs/ml_expressions/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:
