# %%
import requests
import os
from PIL import Image
from io import BytesIO
from datetime import datetime
from dotenv import load_dotenv
import time
import json
from pathlib import Path

# %%
# Directory to save downloaded pexels images
SAVE_DIR = "/Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped"
os.makedirs(SAVE_DIR, exist_ok=True)
file_path="/Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_scraped/downloaded_urls_pexels_2025.json"

# %%
# Pexels URL
PEXELS_API_URL = "https://api.pexels.com/v1/search"

# %%
# Persistent Tracking: Load previously downloaded URLs
def load_downloaded_urls(file_path):
    if os.path.exists(file_path):
        try:
            with open(file_path, "r") as f:
                urls = set(json.load(f))
            print(f"Loaded {len(urls)} previously downloaded URLs from {file_path}.")
            return urls
        except json.JSONDecodeError:
            print(f"Warning: {file_path} is empty or corrupted. Starting fresh for this query.")
            return set()
    return set()

# %%
# Persistent Tracking: Saves downloaded URLs to specific JSON file
def save_downloaded_urls(downloaded_urls, file_path):
    with open(file_path, "w") as f:
        json.dump(list(downloaded_urls), f, indent=4)
    print(f"Saved {len(downloaded_urls)} downloaded URLs to {file_path}.")

# %%
# Recursively scans all subdirectories in the root_dir to find the
    # highest number in filenames like 'image_xxxx.jpg'
def find_highest_image_number(root_dir):
    highest_num = 0
    root_path = Path(root_dir)
    
    # Use rglob to find all matching files recursively
    all_image_files = list(root_path.rglob("image_*.jpg")) + list(root_path.rglob("image_*.jpeg"))
    
    for file_path in all_image_files:
        try:
            # Extracts the number part from "image_1234.jpg"
            num_str = file_path.stem.split('_')[1]
            num = int(num_str)
            if num > highest_num:
                highest_num = num
        except (IndexError, ValueError):
            # Ignores files that don't match the expected "image_xxxx" format
            continue
            
    print(f"Found highest existing image number: {highest_num}")
    return highest_num

# %%
# Returns a list of diverse, URL-formatted search queries to find natural human expressions
def generate_pexels_queries():

    # Using '+' for URL encoding
    queries = [
        "spectator+reaction","fan+celebration", "commuter", "person+laughing", 
        "heated+discussion","intense+concentration", "joyful", "pensive+person", 
        "annoyed+face","worried+person", "thoughtful+expression", "people+talking", 
        "faces", "smiling", "groups", "friends", "family", "couples", "individuals", 
        "emotions", "sad", "angry", "happy", "joyful","suspicious", "disgust","fear", 
        "rage","human faces","profession", "human", "people", "portraits", "contempt", 
        "candid+portrait", "street+photography"
    ]
    return queries

# %%
# Exhaustively fetches and saves images for a SINGLE query, saving all files
    # and tracking information into the specified 'save_dir'
    # Returns the number of images it successfully downloaded
def auto_pexels_images(api_key, query, save_dir, start_index, max_api_calls=200, batch_size=80):
    
    PEXELS_API_URL = "https://api.pexels.com/v1/search"
    MAX_RETRIES = 3
    api_call_count = 0
    page = 1
    
    tracking_file_path = os.path.join(save_dir, "downloaded_urls.json")
    downloaded_urls = load_downloaded_urls(tracking_file_path)

    total_downloaded_for_query = 0

    while api_call_count < max_api_calls:
        headers = {"Authorization": api_key}
        params = {"query": query, "per_page": batch_size, "page": page}

        try:
            response = requests.get(PEXELS_API_URL, headers=headers, params=params)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"API request failed: {e}. Stopping this query.")
            break
            
        api_call_count += 1
        print(f"API Call {api_call_count}/{max_api_calls} for query '{query}', page {page}.")

        data = response.json()
        photos = data.get("photos", [])

        if not photos:
            print(f"No more photos found for query '{query}'. This query is complete.")
            break

        new_downloads_this_page = 0
        for photo in photos:
            image_url = photo["src"]["original"]
            if image_url in downloaded_urls:
                continue

            metadata = {
                "photographer": photo.get("photographer"),
                "photographer_url": photo.get("photographer_url"),
                "pexels_url": photo.get("url"),
                "source_url": image_url
            }

            for attempt in range(MAX_RETRIES):
                try:
                    dl_response = requests.get(image_url, timeout=120)
                    dl_response.raise_for_status()
                    
                    # MODIFIED: Use the start_index passed to the function
                    filename_base = f"image_{start_index + total_downloaded_for_query:04d}" # Added 4-digit padding
                    image_filename = os.path.join(save_dir, f"{filename_base}.jpg")
                    metadata_filename = os.path.join(save_dir, f"{filename_base}.json")

                    with open(image_filename, "wb") as f:
                        f.write(dl_response.content)
                    
                    with open(metadata_filename, "w") as f:
                        json.dump(metadata, f, indent=4)
                    
                    print(f"  Success: Downloaded {image_filename} and its metadata.")
                    downloaded_urls.add(image_url)
                    save_downloaded_urls(downloaded_urls, tracking_file_path)
                    
                    total_downloaded_for_query += 1
                    new_downloads_this_page += 1
                    break
                except requests.exceptions.RequestException as e:
                    print(f"  Attempt {attempt + 1} failed for {image_url}: {e}")
                    if attempt == MAX_RETRIES - 1:
                        print(f"  Failed to download after {MAX_RETRIES} attempts.")
        
        if new_downloads_this_page == 0 and len(photos) > 0:
            print(f"No new images found on page {page}. Assuming query '{query}' is complete.")
            break
        
        page += 1
        time.sleep(1)

    print(f"\nFinished query '{query}'. Downloaded a total of {total_downloaded_for_query} new images for this query.")
    return total_downloaded_for_query

# %%
# --- MAIN EXECUTION BLOCK ---

if __name__ == "__main__":
    
    os.makedirs(SAVE_DIR, exist_ok=True)

    # Load variables from .env
    load_dotenv()

    PEXELS_API_KEY = os.getenv("PEXELS_API_KEY")

    if not PEXELS_API_KEY:
        raise ValueError("PEXELS_API_KEY not found in .env file")
    
    # 1. Find the highest existing number across all subfolders first.
    highest_number = find_highest_image_number(SAVE_DIR)
    current_image_counter = highest_number + 1
    print(f"Starting new session. Numbering will begin at: {current_image_counter}")
    
    all_queries = generate_pexels_queries()
    print(f"Found {len(all_queries)} queries to process for Pexels.\n{'='*50}")

    for query in all_queries:
        print(f"\nProcessing query: '{query}'")
        
        output_folder_for_query = os.path.join(SAVE_DIR, query.replace('+', '_'))
        os.makedirs(output_folder_for_query, exist_ok=True)
        
        # 2. Pass the current counter and get back the number of new files.
        newly_downloaded_count = auto_pexels_images(
            api_key=PEXELS_API_KEY,
            query=query,
            save_dir=output_folder_for_query,
            start_index=current_image_counter,
            max_api_calls=200,
            batch_size=80
        )
        # 3. Increment the main counter.
        current_image_counter += newly_downloaded_count

        print(f"{'='*50}")

    print(f"\nAll queries have been processed. Next session will start after image_{current_image_counter - 1}.")
# Out:
# Found highest existing image number: 52253
# Starting new session. Numbering will begin at: 52254
# Found 36 queries to process for Pexels.
# ==================================================
#
# Processing query: 'spectator+reaction'
# Loaded 295 previously downloaded URLs from /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
# API Call 1/200 for query 'spectator+reaction', page 1.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52254.jpg and its metadata.
# Saved 296 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52255.jpg and its metadata.
# Saved 297 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52256.jpg and its metadata.
# Saved 298 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52257.jpg and its metadata.
# Saved 299 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52258.jpg and its metadata.
# Saved 300 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/image_52259.jpg and its metadata.
# Saved 301 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/spectator_reaction/downloaded_urls.json.
# API Call 2/200 for query 'spectator+reaction', page 2.
# No new images found on page 2. Assuming query 'spectator+reaction' is complete.
#
# Finished query 'spectator+reaction'. Downloaded a total of 6 new images for this query.
# ==================================================
#
# Processing query: 'fan+celebration'
# Loaded 8262 previously downloaded URLs from /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
# API Call 1/200 for query 'fan+celebration', page 1.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52260.jpg and its metadata.
# Saved 8263 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52261.jpg and its metadata.
# Saved 8264 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52262.jpg and its metadata.
# Saved 8265 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52263.jpg and its metadata.
# Saved 8266 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52264.jpg and its metadata.
# Saved 8267 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52265.jpg and its metadata.
# Saved 8268 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52266.jpg and its metadata.
# Saved 8269 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52267.jpg and its metadata.
# Saved 8270 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52268.jpg and its metadata.
# Saved 8271 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52269.jpg and its metadata.
# Saved 8272 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52270.jpg and its metadata.
# Saved 8273 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52271.jpg and its metadata.
# Saved 8274 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52272.jpg and its metadata.
# Saved 8275 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52273.jpg and its metadata.
# Saved 8276 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52274.jpg and its metadata.
# Saved 8277 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52275.jpg and its metadata.
# Saved 8278 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52276.jpg and its metadata.
# Saved 8279 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52277.jpg and its metadata.
# Saved 8280 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52278.jpg and its metadata.
# Saved 8281 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52279.jpg and its metadata.
# Saved 8282 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52280.jpg and its metadata.
# Saved 8283 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52281.jpg and its metadata.
# Saved 8284 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52282.jpg and its metadata.
# Saved 8285 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52283.jpg and its metadata.
# Saved 8286 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52284.jpg and its metadata.
# Saved 8287 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52285.jpg and its metadata.
# Saved 8288 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52286.jpg and its metadata.
# Saved 8289 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52287.jpg and its metadata.
# Saved 8290 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52288.jpg and its metadata.
# Saved 8291 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52289.jpg and its metadata.
# Saved 8292 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52290.jpg and its metadata.
# Saved 8293 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52291.jpg and its metadata.
# Saved 8294 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52292.jpg and its metadata.
# Saved 8295 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52293.jpg and its metadata.
# Saved 8296 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52294.jpg and its metadata.
# Saved 8297 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52295.jpg and its metadata.
# Saved 8298 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52296.jpg and its metadata.
# Saved 8299 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52297.jpg and its metadata.
# Saved 8300 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52298.jpg and its metadata.
# Saved 8301 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52299.jpg and its metadata.
# Saved 8302 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52300.jpg and its metadata.
# Saved 8303 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52301.jpg and its metadata.
# Saved 8304 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52302.jpg and its metadata.
# Saved 8305 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52303.jpg and its metadata.
# Saved 8306 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52304.jpg and its metadata.
# Saved 8307 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52305.jpg and its metadata.
# Saved 8308 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52306.jpg and its metadata.
# Saved 8309 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52307.jpg and its metadata.
# Saved 8310 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52308.jpg and its metadata.
# Saved 8311 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52309.jpg and its metadata.
# Saved 8312 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52310.jpg and its metadata.
# Saved 8313 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52311.jpg and its metadata.
# Saved 8314 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52312.jpg and its metadata.
# Saved 8315 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52313.jpg and its metadata.
# Saved 8316 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52314.jpg and its metadata.
# Saved 8317 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52315.jpg and its metadata.
# Saved 8318 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52316.jpg and its metadata.
# Saved 8319 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52317.jpg and its metadata.
# Saved 8320 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52318.jpg and its metadata.
# Saved 8321 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52319.jpg and its metadata.
# Saved 8322 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52320.jpg and its metadata.
# Saved 8323 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52321.jpg and its metadata.
# Saved 8324 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52322.jpg and its metadata.
# Saved 8325 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52323.jpg and its metadata.
# Saved 8326 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52324.jpg and its metadata.
# Saved 8327 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52325.jpg and its metadata.
# Saved 8328 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52326.jpg and its metadata.
# Saved 8329 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52327.jpg and its metadata.
# Saved 8330 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52328.jpg and its metadata.
# Saved 8331 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52329.jpg and its metadata.
# Saved 8332 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52330.jpg and its metadata.
# Saved 8333 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52331.jpg and its metadata.
# Saved 8334 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52332.jpg and its metadata.
# Saved 8335 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52333.jpg and its metadata.
# Saved 8336 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52334.jpg and its metadata.
# Saved 8337 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52335.jpg and its metadata.
# Saved 8338 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52336.jpg and its metadata.
# Saved 8339 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
#   Success: Downloaded /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/image_52337.jpg and its metadata.
# Saved 8340 downloaded URLs to /Users/natalyagrokh/AI/ml_expressions/img_datasets/pexels_dataset_archive/pexels_scraped/fan_celebration/downloaded_urls.json.
