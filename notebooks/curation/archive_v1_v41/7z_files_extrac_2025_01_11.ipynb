# %%
import os
import subprocess

# %%
# Define the directory containing the .7z files
source_directory = "/home/natalyagrokh/img_datasets/celeba_dataset"
target_directory = "/home/natalyagrokh/img_datasets/celeba_dataset/extracted_images"

# %%
# Ensure the target directory exists
os.makedirs(target_directory, exist_ok=True)

# %%
# Command to extract the 7z file
command = [
    "7z", "x", source_file,
    f"-o{target_directory}"  # Specify the output directory
]

# %%
# Execute the command
print(f"Extracting: {source_file} -> {target_directory}")
try:
    result = subprocess.run(command, check=True, text=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Extraction completed successfully!")
    print(result.stdout)  # Optional: Print 7z output
except subprocess.CalledProcessError as e:
    print(f"Extraction failed with error: {e.stderr}")
# Out:
# Extracting: /home/natalyagrokh/img_datasets/celeba_dataset/img_align_celeba_png.7z.001 -> /home/natalyagrokh/img_datasets/celeba_dataset/extracted_images
# Extraction completed successfully!
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=C.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 734003200 bytes (700 MiB)
#
# Extracting archive: /home/natalyagrokh/img_datasets/celeba_dataset/img_align_celeba_png.7z.001
# --
# Path = /home/natalyagrokh/img_datasets/celeba_dataset/img_align_celeba_png.7z.001
# Type = Split
# Physical Size = 734003200
# Volumes = 16
# Total Physical Size = 11586962073
# ----
# Path = img_align_celeba_png.7z
# Size = 11586962073
# --
# Path = img_align_celeba_png.7z
# Type = 7z
# Physical Size = 11586962073
# Headers Size = 1977786
# Method = LZMA:24
# Solid = +
# Blocks = 6
#
# Everything is Ok
#
# Folders: 1
# ...
