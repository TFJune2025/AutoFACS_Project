# %%
import os
import shutil

# %%
# Define the source and target directories
source_directory = "/home/natalyagrokh/img_datasets/img_datasets/curated_images/home/natalyagrokh/img_datasets/ck_dataset_filtered"
target_directory = "/home/natalyagrokh/img_datasets/curated_images"

# %%
# Ensure the target directory exists
os.makedirs(target_directory, exist_ok=True)

# %%
# Define the list of image file extensions to look for
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff")

# %%
# Walk through the source directory and find image files
for root, dirs, files in os.walk(source_directory):
    for file in files:
        # Check if the file is an image
        if file.lower().endswith(image_extensions):
            source_file = os.path.join(root, file)
            target_file = os.path.join(target_directory, file)
            
            # Move the file to the target directory
            try:
                shutil.move(source_file, target_file)
                print(f"Moved: {source_file} -> {target_file}")
            except Exception as e:
                print(f"Failed to move {source_file}: {e}")

print("All image files have been moved!")
# Out:
# All image files have been moved!
